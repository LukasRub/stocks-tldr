# %%
import re
import json
import pprint
from collections import Counter

import pandas as pd
from bs4 import BeautifulSoup

PATH_TO_DATA = "../../data/raw/WashingtonPost.v4/data/TREC_Washington_Post_collection.v4.jl"
pp = pprint.PrettyPrinter(indent=1, compact=False)

# %% [markdown]
# ### Exploring the structure of the dataset

# %%
top_level_attribs = Counter()
content_types_subtypes = Counter()

with open(PATH_TO_DATA, 'r', encoding='utf8') as fp:
    for line in fp.readlines():
        decoded_json = json.loads(line)
        
        top_level_attribs.update(decoded_json.keys())
    
        for content_piece in decoded_json["contents"]:
            if (content_piece is not None):
                if "subtype" in content_piece.keys():
                    key = "{}+{}".format(content_piece["type"], content_piece["subtype"])                    
                else:
                    key = content_piece["type"]
                content_types_subtypes[key] += 1

# %%
top_level_attribs.most_common()
# Out:
# [('id', 728626),
#  ('article_url', 728626),
#  ('title', 728626),
#  ('author', 728626),
#  ('contents', 728626),
#  ('content', 671947),
#  ('published_date', 517530),
#  ('type', 517530),
#  ('source', 517530),
#  ('publish_date', 56679),
#  ('orig-id', 2579)]

# %%
content_types_subtypes.most_common()
# Out:
# [('sanitized_html+paragraph', 14704450),
#  ('date', 728623),
#  ('title', 718741),
#  ('kicker', 718464),
#  ('byline', 670249),
#  ('image', 556142),
#  ('author_info', 399237),
#  ('sanitized_html+subhead', 177310),
#  ('sanitized_html+blockquote', 175624),
#  ('tweet', 127961),
#  ('sanitized_html+sublabel', 116428),
#  ('video', 100727),
#  ('gallery', 34713),
#  ('list', 23278),
#  ('sanitized_html+p1', 18030),
#  ('sanitized_html+trailleft', 17351),
#  ('sanitized_html+h2', 9984),
#  ('sanitized_html+h3', 9551),
#  ('instagram', 8269),
#  ('deck', 7092),
#  ('sanitized_html+liveblog-cf liveblog-entry-meta', 6806),
#  ('sanitized_html+liveblog-entry-content', 6648),
#  ('sanitized_html+dateline', 5265),
#  ('sanitized_html+strong', 4560),
#  ('sanitized_html+10pt-top', 4302),
#  ('sanitized_html+table', 3125),
#  ('sanitized_html+caption padding-left border-left', 2842),
#  ('sanitized_html+correction', 2768),
#  ('sanitized_html+digital-headgroup', 2442),
#  ('sanitized_html+attachment', 2173),
#  ('sanitized_html+p2', 2136),
#  ('sanitized_html+x_MsoNormal', 1815),
#  ('sanitized_html+trailcenter', 1789),
#  ('sanitized_html+0pt', 1717),
#  ('sanitized_html+story-body-text story-content', 1692),
#  ('sanitized_html+booktitle', 1478),
#  ('sanitized_html+content', 1466),
#  ('sanitized_html+h4', 1429),
#  ('sanitized_html+MsoNormal', 1351),
#  ('sanitized_html+h1', 1328),
#  ('sanitized_html+RedArrow', 1322),
#  ('sanitized_html+fb-xfbml-parse-ignore', 1205),
#  ('sanitized_html+intro', 1129),
#  ('sanitized_html+stars', 1029),
#  ('sanitized_html+em', 1019),
#  ('sanitized_html+boldlede', 847),
#  ('sanitized_html+criticstars', 822),
#  ('sanitized_html+chart-group', 779),
#  ('sanitized_html+span', 649),
#  ('sanitized_html+b', 643),
#  ('sanitized_html+no-skin flex-item flex-stack text-align-left equalize-height-target',
#   629),
#  ('sanitized_html+address', 623),
#  ('sanitized_html+clear', 617),
#  ('sanitized_html+style', 583),
#  ('sanitized_html+p3', 550),
#  ('sanitized_html+ReportText', 510),
#  ('sanitized_html+blog_caption', 509),
#  ('sanitized_html+pb-container', 498),
#  ('sanitized_html+noscript', 453),
#  ('sanitized_html+i', 411),
#  ('sanitized_html+zn-body__paragraph', 393),
#  ('sanitized_html+h5', 378),
#  ('sanitized_html+quoteTable', 370),
#  ('sanitized_html+hotTable', 357),
#  ('sanitized_html+twitter-video', 345),
#  ('sanitized_html+byline-text', 336),
#  ('sanitized_html+loose', 336),
#  ('sanitized_html+r', 315),
#  ('sanitized_html+box', 281),
#  ('sanitized_html+info', 279),
#  ('sanitized_html+wp-row', 278),
#  ('sanitized_html+data-table', 248),
#  ('sanitized_html+10pt', 239),
#  ('sanitized_html+mapbox-map', 233),
#  ('sanitized_html+margin-bottom', 231),
#  ('sanitized_html+InviteTease', 222),
#  ('sanitized_html+WinText', 221),
#  ('sanitized_html+p4', 220),
#  ('sanitized_html+hidden-data revere-stub', 218),
#  ('pull_quote', 208),
#  ('sanitized_html+@notes', 204),
#  ('sanitized_html+wp-caption aligncenter', 192),
#  ('sanitized_html+story-body-text', 183),
#  ('sanitized_html+FourText', 177),
#  ('sanitized_html+left padding-left-5 padding-right-5 padding-top padding-bottom-20 natcast-logo',
#   176),
#  ('sanitized_html+quote', 173),
#  ('sanitized_html+fb-post', 168),
#  ('sanitized_html+trailer', 166),
#  ('sanitized_html+subscribe-box', 165),
#  ('sanitized_html+fdateline', 164),
#  ('sanitized_html+center', 153),
#  ('sanitized_html+canvas-text Mb(1.0em) Mb(0)--sm Mt(0.8em)--sm canvas-atom',
#   147),
#  ('sanitized_html+headgroup', 146),
#  ('sanitized_html+object', 145),
#  ('sanitized_html+x_p1', 126),
#  ('sanitized_html+datelab-container', 123),
#  ('sanitized_html+MsoPlainText', 118),
#  ('sanitized_html+bodytext', 116),
#  ('sanitized_html+p5', 115),
#  ('sanitized_html+dl', 112),
#  ('sanitized_html+gmail-p1', 112),
#  ('sanitized_html+padding-bottom-15', 109),
#  ('sanitized_html+daily-slogan padding-right-20 margin-right-20', 108),
#  ('sanitized_html+caption', 106),
#  ('sanitized_html+ap-story-p', 101),
#  ('sanitized_html+Body', 98),
#  ('sanitized_html+package-title oxford', 94),
#  ('sanitized_html+wp-row border-bottom', 94),
#  ('sanitized_html+selectionShareable', 94),
#  ('sanitized_html+show', 93),
#  ('sanitized_html+article', 89),
#  ('sanitized_html+gallery-item', 88),
#  ('sanitized_html+imgur-embed-pub', 87),
#  ('sanitized_html+ingredient-list', 86),
#  ('sanitized_html+western', 86),
#  ('sanitized_html+graf--p', 83),
#  ('sanitized_html+wp-row border-bottom-2', 82),
#  ('sanitized_html+pgh-paragraph', 82),
#  ('sanitized_html+layoutArea', 80),
#  ('sanitized_html+gallery-caption border-bottom relative margin-bottom', 74),
#  ('sanitized_html+pg-intro', 73),
#  ('sanitized_html+fb-video', 72),
#  ('sanitized_html+text', 70),
#  ('sanitized_html+gmail-msonospacing', 70),
#  ('sanitized_html+BigNumber', 69),
#  ('sanitized_html+tumblr-post', 63),
#  ('sanitized_html+ember-view', 62),
#  ('sanitized_html+x_MsoNoSpacing', 62),
#  ('sanitized_html+row', 61),
#  ('sanitized_html+body', 59),
#  ('sanitized_html+gfx-jpt', 58),
#  ('sanitized_html+inlineMedia inlineMedia-VIDEO', 57),
#  ('sanitized_html+roundup', 57),
#  ('sanitized_html+moat-trackable pb-f-theme-normal pb-feature pb-layout-item pb-f-sharebars-top-share-bar',
#   57),
#  ('sanitized_html+Standard', 57),
#  ('sanitized_html+Text_Body', 52),
#  ('sanitized_html+wordsection1', 51),
#  ('sanitized_html+wp-audio-shortcode', 51),
#  ('sanitized_html+topline', 49),
#  ('sanitized_html+tableauViz', 48),
#  ('sanitized_html+links', 47),
#  ('sanitized_html+pre', 47),
#  ('sanitized_html+no-skin flex-item flex-stack  text-align-left  equalize-height-target',
#   46),
#  ('sanitized_html+p-block', 45),
#  ('sanitized_html+Normal1', 44),
#  ('sanitized_html+relative gallery-container', 43),
#  ('sanitized_html+normal', 43),
#  ('sanitized_html+article-body', 43),
#  ('sanitized_html+firstgraf', 39),
#  ('sanitized_html+graf graf--p graf-after--p', 39),
#  ('sanitized_html+wp-caption alignnone', 38),
#  ('sanitized_html+_baseTweetText _tweetText messageContent', 38),
#  ('sanitized_html+li', 37),
#  ('sanitized_html+left padding-left-5 padding-right-5 padding-top padding-bottom-20 unitedcast-logo',
#   37),
#  ('sanitized_html+TEXT_w_Indent', 37),
#  ('sanitized_html+h6', 36),
#  ('sanitized_html+pb-caption', 35),
#  ('sanitized_html+canvas-atom canvas-text Mb(1.0em) Mb(0)--sm Mt(0.8em)--sm',
#   34),
#  ('sanitized_html+wp-video-shortcode', 33),
#  ('sanitized_html+sub', 32),
#  ('sanitized_html+marB10', 32),
#  ('sanitized_html+xmsonormal', 31),
#  ('sanitized_html+story-body__introduction', 31),
#  ('sanitized_html+MsoNoSpacing', 30),
#  ('sanitized_html+dialogue', 30),
#  ('sanitized_html+gmail-p2', 30),
#  ('sanitized_html+closings', 29),
#  ('sanitized_html+heading', 29),
#  ('sanitized_html+sup', 28),
#  ('sanitized_html+section', 28),
#  ('sanitized_html+x_Body', 28),
#  ('sanitized_html+story-txt', 28),
#  ('sanitized_html+padding border', 27),
#  ('sanitized_html+wp-caption-dt', 27),
#  ('sanitized_html+p7', 27),
#  ('sanitized_html+p-text', 27),
#  ('sanitized_html+article-video border-top border-top padding-top padding-bottom margin-bottom photo-wrapper',
#   26),
#  ('sanitized_html+alignright padding-bottom padding-left', 26),
#  ('sanitized_html+body-el-text longform-body-el-text', 26),
#  ('sanitized_html+print-label', 25),
#  ('sanitized_html+showlink', 25),
#  ('sanitized_html+p6', 25),
#  ('sanitized_html+TX Body', 25),
#  ('sanitized_html+c0', 24),
#  ('sanitized_html+m_7282176024471021928m_627373439130447667gmail-normal', 24),
#  ('sanitized_html+story-map', 23),
#  ('sanitized_html+alignright padding-bottom', 23),
#  ('sanitized_html+ecxMsoNormal', 23),
#  ('sanitized_html+LO-normal', 22),
#  ('sanitized_html+zipper', 21),
#  ('sanitized_html+background', 21),
#  ('sanitized_html+ecxmsonormal', 21),
#  ('sanitized_html+title', 20),
#  ('sanitized_html+series-bug', 20),
#  ('sanitized_html+playerTableTable tableBody', 20),
#  ('sanitized_html+border-bottom-off', 20),
#  ('sanitized_html+story-headline', 20),
#  ('sanitized_html+qtext_para', 20),
#  ('sanitized_html+clay-paragraph', 20),
#  ('sanitized_html+zn-bodyparagraph', 19),
#  ('sanitized_html+graf--p graf-after--p', 19),
#  ('sanitized_html+player-rank', 19),
#  ('sanitized_html+graf graf--p graf-after--figure', 19),
#  ('sanitized_html+pb-feed-headline', 18),
#  ('sanitized_html+CenteredReadOut', 18),
#  ('sanitized_html+wp-embedded-content', 18),
#  ('sanitized_html+clipper--hidden', 18),
#  ('sanitized_html+print-only', 17),
#  ('sanitized_html+ricoh-theta-spherical-image', 17),
#  ('inline_story', 17),
#  ('sanitized_html+graf graf--p', 17),
#  ('sanitized_html+headline', 16),
#  ('sanitized_html+p8', 16),
#  ('sanitized_html+tableizer-table', 16),
#  ('sanitized_html+DV-textContents', 16),
#  ('sanitized_html+gmail-msonormal', 16),
#  ('sanitized_html+newsletter-inline-unit codedNewsletter ', 16),
#  ('sanitized_html+speakable-p-1 p-text', 16),
#  ('sanitized_html+numbers', 15),
#  ('sanitized_html+wp-caption alignleft', 15),
#  ('sanitized_html+x_unIndentedList', 15),
#  ('sanitized_html+graf--p graf--startsWithDoubleQuote', 15),
#  ('sanitized_html+qualified qualified-1', 15),
#  ('sanitized_html+border-bottom-off border-bottom-', 15),
#  ('sanitized_html+v2-processed', 15),
#  ('sanitized_html+small', 14),
#  ('sanitized_html+lead', 14),
#  ('sanitized_html+Abs15', 14),
#  ('sanitized_html+x_MsoPlainText', 14),
#  ('sanitized_html+x_wordsection1', 14),
#  ('sanitized_html+x_x_MsoNormal', 14),
#  ('sanitized_html+ent-photo-grid-small-caption', 14),
#  ('sanitized_html+m_4557195882978389762gmail-p1', 14),
#  ('sanitized_html+MsoBodyText', 13),
#  ('sanitized_html+bio', 13),
#  ('sanitized_html+left padding-left-5 padding-right-5 padding-top padding-bottom-20 skinscast-logo',
#   13),
#  ('sanitized_html+opbandit', 13),
#  ('sanitized_html+align-centre', 13),
#  ('sanitized_html+align-centre zoomable', 13),
#  ('sanitized_html+align-center', 13),
#  ('sanitized_html+permalinkable', 13),
#  ('sanitized_html+rg_standalone_container', 13),
#  ('sanitized_html+visually_embed_bar', 12),
#  ('sanitized_html+ListParagraph', 12),
#  ('sanitized_html+form', 12),
#  ('sanitized_html+First PreviewPagemarker', 12),
#  ('sanitized_html+Tab-body-text TAB', 12),
#  ('sanitized_html+aging-subhead', 12),
#  ('sanitized_html+qtext_para subhead', 12),
#  ('sanitized_html+NormalParagraphStyle', 12),
#  ('sanitized_html+root', 11),
#  ('sanitized_html+wordpress', 11),
#  ('sanitized_html+wp-caption alignright', 11),
#  ('sanitized_html+a-size-large a-spacing-none', 11),
#  ('sanitized_html+article-topper', 11),
#  ('sanitized_html+BodyA', 11),
#  ('sanitized_html+font_7', 11),
#  ('sanitized_html+para', 11),
#  ('sanitized_html+Bodytext', 11),
#  ('sanitized_html+rtejustify', 11),
#  ('sanitized_html+wpview-selection-after', 11),
#  ('sanitized_html+GDT-GDT STORY Text', 11),
#  ('sanitized_html+ent-b-caption', 11),
#  ('sanitized_html+ng-binding ng-scope', 11),
#  ('sanitized_html+losers', 10),
#  ('sanitized_html+iframe', 10),
#  ('sanitized_html+relative ', 10),
#  ('sanitized_html+heading heading3', 10),
#  ('sanitized_html+intro pg-dropCap pg-dropCap--sans', 10),
#  ('sanitized_html+header', 10),
#  ('sanitized_html+del', 10),
#  ('sanitized_html+js-tweet-text tweet-text', 10),
#  ('sanitized_html+p1 subhead', 10),
#  ('sanitized_html+font_8', 10),
#  ('sanitized_html+newsletter-inline-unit container codedNewsletter ', 10),
#  ('sanitized_html+headline small normal-style text-align-inherit ', 10),
#  ('sanitized_html+sidenote', 9),
#  ('sanitized_html+t_Content', 9),
#  ('sanitized_html+cnn_storypgraphtxt cnn_storypgraph13', 9),
#  ('sanitized_html+econoevents', 9),
#  ('sanitized_html+align-center zoomable', 9),
#  ('sanitized_html+table table-striped', 9),
#  ('sanitized_html+TweetTextSize js-tweet-text tweet-text', 9),
#  ('sanitized_html+body-el-text standard-body-el-text', 9),
#  ('sanitized_html+count_el', 9),
#  ('sanitized_html+m_-6868620953563807351gmail-p1', 9),
#  ('sanitized_html+graf graf--p graf--startsWithDoubleQuote', 9),
#  ('sanitized_html+_5pbw _5vra', 9),
#  ('sanitized_html+dots', 8),
#  ('sanitized_html+left forensics-type', 8),
#  ('sanitized_html+election-promo', 8),
#  ('sanitized_html+series', 8),
#  ('sanitized_html+external-game-embed', 8),
#  ('sanitized_html+pg-dropCap', 8),
#  ('sanitized_html+secondline', 8),
#  ('sanitized_html+issue', 8),
#  ('sanitized_html+what-make', 8),
#  ('sanitized_html+MsoNormalTable', 8),
#  ('sanitized_html+PTRANS', 8),
#  ('sanitized_html+tr_bq', 8),
#  ('sanitized_html+cnn_storypgraphtxt cnn_storypgraph2', 8),
#  ('sanitized_html+ng-scope', 8),
#  ('sanitized_html+p9', 8),
#  ('sanitized_html+verse', 8),
#  ('sanitized_html+article-paragraph p-7', 8),
#  ('sanitized_html+ui-droppable', 8),
#  ('sanitized_html+page', 8),
#  ('sanitized_html+test', 8),
#  ('sanitized_html+wpview-selection-before', 8),
#  ('sanitized_html+ wp-image-22179', 8),
#  ('sanitized_html+story-body story-body-1', 8),
#  ('sanitized_html+speakable-p-2 p-text', 8),
#  ('sanitized_html+twitter-timeline', 7),
#  ('sanitized_html+photo-caption', 7),
#  ('sanitized_html+sampling', 7),
#  ('sanitized_html+franklin', 7),
#  ('sanitized_html+chapter', 7),
#  ('sanitized_html+outcome', 7),
#  ('sanitized_html+pg-bodyCopy pg-dropCap', 7),
#  ('sanitized_html+DV-container', 7),
#  ('sanitized_html+cnn_storypgraphtxt cnn_storypgraph4', 7),
#  ('sanitized_html+first-text', 7),
#  ('sanitized_html+firstHeading', 7),
#  ('sanitized_html+p', 7),
#  ('sanitized_html+encrypted-content', 7),
#  ('sanitized_html+credit', 7),
#  ('sanitized_html+ap_para ap_para-d57851005a80479aaeeb90a12c70b9f6 entry-content',
#   7),
#  ('sanitized_html+opinion_text', 7),
#  ('sanitized_html+News-body-text', 7),
#  ('sanitized_html+ProfileHeaderCard-name', 7),
#  ('sanitized_html+fr-tag', 7),
#  ('sanitized_html+BodyText-BodyText_Tagline_Cutoff', 7),
#  ('sanitized_html+_209g', 7),
#  ('sanitized_html+last', 7),
#  ('sanitized_html+subscriber-only', 7),
#  ('sanitized_html+body-text', 7),
#  ('sanitized_html+Newstext', 7),
#  ('sanitized_html+g-body', 7),
#  ('sanitized_html+message_body', 7),
#  ('sanitized_html+st', 7),
#  ('sanitized_html+x_p4', 7),
#  ('sanitized_html+x_m_-4062188367447471207m_-3494790748499559579MsoNoSpacing',
#   7),
#  ('sanitized_html+p1 body-el-text standard-body-el-text', 7),
#  ('sanitized_html+speakable', 7),
#  ('sanitized_html+byline-box', 6),
#  ('sanitized_html+”heading', 6),
#  ('sanitized_html+article-video border-top border-bottom padding-top padding-bottom margin-bottom photo-wrapper',
#   6),
#  ('sanitized_html+newaps', 6),
#  ('sanitized_html+wp-row border-bottom padding-bottom margin-bottom', 6),
#  ('sanitized_html+special', 6),
#  ('sanitized_html+xxmsonormal', 6),
#  ('sanitized_html+rep', 6),
#  ('sanitized_html+drop-cap', 6),
#  ('sanitized_html+inline', 6),
#  ('sanitized_html+rg3-cutout', 6),
#  ('sanitized_html+clearfix', 6),
#  ('sanitized_html+cnn_storypgraphtxt cnn_storypgraph8', 6),
#  ('sanitized_html+size-medium', 6),
#  ('sanitized_html+cnn_storypgraphtxt cnn_storypgraph5', 6),
#  ('sanitized_html+listings-details-body', 6),
#  ('sanitized_html+statutory-body', 6),
#  ('sanitized_html+cnn_storypgraphtxt cnn_storypgraph18', 6),
#  ('sanitized_html+s4', 6),
#  ('sanitized_html+dropcapfancy', 6),
#  ('sanitized_html+story-body-text subhead', 6),
#  ('sanitized_html+sub_buzz_desc_w_attr', 6),
#  ('sanitized_html+News-brief-text', 6),
#  ('sanitized_html+single', 6),
#  ('sanitized_html+m_-7771258406795307763MsoPlainText', 6),
#  ('sanitized_html+body-text__paragraph-text', 6),
#  ('sanitized_html+ent-photo-caption', 6),
#  ('sanitized_html+arrow', 5),
#  ('sanitized_html+frac', 5),
#  ('sanitized_html+dem', 5),
#  ('sanitized_html+align-right zoomable', 5),
#  ('sanitized_html+Ct', 5),
#  ('sanitized_html+entry-content', 5),
#  ('sanitized_html+r _U6c', 5),
#  ('sanitized_html+entry-header', 5),
#  ('sanitized_html+gmail_signature', 5),
#  ('sanitized_html+wp-caption align center', 5),
#  ('sanitized_html+p-block a-ok', 5),
#  ('sanitized_html+glossaryProduct updatedoff', 5),
#  ('sanitized_html+pane-content', 5),
#  ('sanitized_html+wrap', 5),
#  ('sanitized_html+x_MsoNormal subhead', 5),
#  ('sanitized_html+sqs-block-content', 5),
#  ('sanitized_html+x_zn-body__paragraph', 5),
#  ('sanitized_html+field-items', 5),
#  ('sanitized_html+s15', 5),
#  ('sanitized_html+hide-in-mobile', 5),
#  ('sanitized_html+inside-copy', 5),
#  ('sanitized_html+sp-story-body__introduction', 5),
#  ('sanitized_html+titlebarTextWrapper', 5),
#  ('sanitized_html+C01PointnumeroteAltN', 5),
#  ('sanitized_html+gmail-p3', 5),
#  ('sanitized_html+tg', 5),
#  ('sanitized_html+m_-1004887157860243029gmail-p3', 5),
#  ('sanitized_html+ent-firstgraf', 5),
#  ('sanitized_html+pg-sans', 5),
#  ('sanitized_html+reddit-embed', 5),
#  ('sanitized_html+trailleft @notes', 4),
#  ('sanitized_html+close', 4),
#  ('sanitized_html+stars @notes', 4),
#  ('sanitized_html+appId sub', 4),
#  ('sanitized_html+kmap-theme-buttons', 4),
#  ('sanitized_html+inline-video-caption', 4),
#  ('sanitized_html+list', 4),
#  ('sanitized_html+big-quote', 4),
#  ('sanitized_html+big-quote-attribution', 4),
#  ('sanitized_html+attrib', 4),
#  ('sanitized_html+hide', 4),
#  ('sanitized_html+hide-graphic', 4),
#  ('sanitized_html+reverse-txt', 4),
#  ('sanitized_html+container', 4),
#  ('sanitized_html+pb-caption kicker caps center', 4),
#  ('sanitized_html+pb-caption center gfx-submit-btn', 4),
#  ('sanitized_html+TEXT-JUSTIFIED-INDENT', 4),
#  ('sanitized_html+align-left zoomable', 4),
#  ('sanitized_html+cnn_storypgraphtxt cnn_storypgraph6', 4),
#  ('sanitized_html+cnn_storypgraphtxt cnn_storypgraph7', 4),
#  ('sanitized_html+gmail_quote', 4),
#  ('sanitized_html+p11', 4),
#  ('sanitized_html+Pioneer 2013-Pioneer.body.copy', 4),
#  ('sanitized_html+ibContent', 4),
#  ('sanitized_html+permalink-header', 4),
#  ('sanitized_html+cnn_storypgraphtxt cnn_storypgraph12', 4),
#  ('sanitized_html+ingredients cf', 4),
#  ('sanitized_html+node', 4),
#  ('sanitized_html+article-paragraph p-9', 4),
#  ('sanitized_html+article-content', 4),
#  ('sanitized_html+location', 4),
#  ('sanitized_html+edTag', 4),
#  ('sanitized_html+group', 4),
#  ('sanitized_html+style143', 4),
#  ('sanitized_html+service-members managed-service', 4),
#  ('sanitized_html+Body copy', 4),
#  ('sanitized_html+CM-Bodycopy-Ragged', 4),
#  ('sanitized_html+article-paragraph p-5', 4),
#  ('sanitized_html+article-paragraph p-13', 4),
#  ('sanitized_html+text_exposed_root text_exposed', 4),
#  ('sanitized_html+google_elide', 4),
#  ('sanitized_html+newsletter-inline-unit codedNewsletter', 4),
#  ('sanitized_html+podcast-tagline', 4),
#  ('sanitized_html+wpv-caption inline-video-caption pb-caption', 4),
#  ('sanitized_html+article-paragraph', 4),
#  ('sanitized_html+moat-trackable pb-f-theme-normal pb-f-dehydrate-false pb-feature pb-layout-item pb-f-sharebars-top-share-bar',
#   4),
#  ('sanitized_html+indent-1', 4),
#  ('top_deck', 4),
#  ('sanitized_html+web-photo', 3),
#  ('sanitized_html+”mapbox-map”', 3),
#  ('sanitized_html+buyitnow', 3),
#  ('sanitized_html+image-audio', 3),
#  ('sanitized_html+tablesorter', 3),
#  ('sanitized_html+photo-double', 3),
#  ('sanitized_html+button-text', 3),
#  ('sanitized_html+first-line dialogue', 3),
#  ('sanitized_html+break', 3),
#  ('sanitized_html+inline last', 3),
#  ('sanitized_html+content-strip', 3),
#  ('sanitized_html+credit border-top', 3),
#  ('sanitized_html+entry-blurb border-bottom margin-bottom', 3),
#  ('sanitized_html+entry-title', 3),
#  ('sanitized_html+ aligncenter', 3),
#  ('sanitized_html+skype_c2c_menu_click2call', 3),
#  ('sanitized_html+skype_c2c_menu_click2sms', 3),
#  ('sanitized_html+skype_c2c_menu_add2skype', 3),
#  ('sanitized_html+has-subscribe-promo borB1S borT1S marB26 padB10 padT10', 3),
#  ('sanitized_html+article-paragraph p-4', 3),
#  ('sanitized_html+headline ', 3),
#  ('sanitized_html+shsTable shsBorderTable', 3),
#  ('sanitized_html+e-entry-title', 3),
#  ('sanitized_html+time', 3),
#  ('sanitized_html+script-tag', 3),
#  ('sanitized_html+cnn_storypgraphtxt cnn_storypgraph34', 3),
#  ('sanitized_html+cnn_storypgraphtxt cnn_storypgraph59', 3),
#  ('sanitized_html+deck', 3),
#  ('sanitized_html+yt subhea; subhead', 3),
#  ('sanitized_html+p10', 3),
#  ('sanitized_html+glossaryProduct ', 3),
#  ('sanitized_html+sub_buzz_desc', 3),
#  ('sanitized_html+indent', 3),
#  ('sanitized_html+story-oembed-wrap ', 3),
#  ('sanitized_html+gs', 3),
#  ('sanitized_html+story', 3),
#  ('sanitized_html+reddit-card', 3),
#  ('sanitized_html+usertext', 3),
#  ('sanitized_html+shsParagraph9', 3),
#  ('sanitized_html+story-intro story-content', 3),
#  ('sanitized_html+align-center ', 3),
#  ('sanitized_html+wrapper text', 3),
#  ('sanitized_html+Tab-brief-text TAB', 3),
#  ('sanitized_html+article-body-p', 3),
#  ('sanitized_html+xxmsoplaintext', 3),
#  ('sanitized_html+newsletter-inline-unit container ', 3),
#  ('sanitized_html+pb-feed-headline ng-scope', 3),
#  ('sanitized_html+no_name', 3),
#  ('sanitized_html+brand-connect-container bc-inline desktop', 3),
#  ('sanitized_html+hs-text-container', 3),
#  ('sanitized_html+thirdpara', 3),
#  ('sanitized_html+no_name selectionShareable', 3),
#  ('sanitized_html+gmailmsg1', 3),
#  ('sanitized_html+loose subhead', 3),
#  ('sanitized_html+pg-bodyCopy', 3),
#  ('sanitized_html+t-body-text', 3),
#  ('sanitized_html+ent-related-links-item', 3),
#  ('sanitized_html+content-list-component bn-content-list-text text', 3),
#  ('sanitized_html+m_-7084018565443621695MsoNormalCxSpMiddle', 3),
#  ('sanitized_html+10pt-top @notes', 2),
#  ('sanitized_html+media', 2),
#  ('sanitized_html+article-video padding-top margin-bottom flipboard-remove',
#   2),
#  ('sanitized_html+tagline', 2),
#  ('sanitized_html+database-promo', 2),
#  ('sanitized_html+tearsheet-header', 2),
#  ('sanitized_html+photo-small', 2),
#  ('sanitized_html+relative primary-slot padding-top img-border photo-wrapper',
#   2),
#  ('sanitized_html+timeline', 2),
#  ('sanitized_html+liveonline', 2),
#  ('sanitized_html+wp-graphics-grade-rg3', 2),
#  ('sanitized_html+piledup-photo', 2),
#  ('sanitized_html+patron-names', 2),
#  ('sanitized_html+photo-change', 2),
#  ('sanitized_html+rapper-name', 2),
#  ('sanitized_html+photo-intro', 2),
#  ('sanitized_html+vote-prompt', 2),
#  ('sanitized_html+user', 2),
#  ('sanitized_html+thanks', 2),
#  ('sanitized_html+size-medium wp-image-182', 2),
#  ('sanitized_html+footer', 2),
#  ('sanitized_html+introduction', 2),
#  ('sanitized_html+copy-paste-block', 2),
#  ('sanitized_html+align-left', 2),
#  ('sanitized_html+size-thumbnail wp-image-30650', 2),
#  ('sanitized_html+body pb40', 2),
#  ('sanitized_html+charthead', 2),
#  ('sanitized_html+incomechart', 2),
#  ('sanitized_html+chartsource', 2),
#  ('sanitized_html+account-group js-account-group js-action-profile js-user-profile-link js-nav',
#   2),
#  ('sanitized_html+BodyB', 2),
#  ('sanitized_html+cnn_storypgraphtxt cnn_storypgraph10', 2),
#  ('sanitized_html+trb_embed ', 2),
#  ('sanitized_html+media-image-wrapper', 2),
#  ('sanitized_html+msgText non-first', 2),
#  ('sanitized_html+answer', 2),
#  ('sanitized_html+cnn_storypgraphtxt cnn_storypgraph19', 2),
#  ('sanitized_html+cnn_storypgraphtxt cnn_storypgraph11', 2),
#  ('sanitized_html+pagpag3', 2),
#  ('sanitized_html+p2 subhead', 2),
#  ('sanitized_html+_baseTweetText _tweetText messageContent subhead', 2),
#  ('sanitized_html+photo_links', 2),
#  ('sanitized_html+photo_caption', 2),
#  ('sanitized_html+FreeFormAA', 2),
#  ('sanitized_html+ng-binding', 2),
#  ('sanitized_html+annotatable', 2),
#  ('sanitized_html+gdp', 2),
#  ('sanitized_html+Bk', 2),
#  ('sanitized_html+posrel cf', 2),
#  ('sanitized_html+video', 2),
#  ('sanitized_html+TweetTextSize TweetTextSize--28px js-tweet-text tweet-text',
#   2),
#  ('sanitized_html+shsParagraph3', 2),
#  ('sanitized_html+glossaryProduct', 2),
#  ('sanitized_html+article-util', 2),
#  ('sanitized_html+body ip-ed ip-af-10380385-BODY ip-s-1740', 2),
#  ('sanitized_html+sanitized_html paragraph', 2),
#  ('sanitized_html+page-region', 2),
#  ('sanitized_html+SCJNumber', 2),
#  ('sanitized_html+js-tweet-text txt-large margin-vl with-linebreaks ', 2),
#  ('sanitized_html+DirectMessage-container', 2),
#  ('sanitized_html+p14', 2),
#  ('sanitized_html+p15', 2),
#  ('sanitized_html+field field-name-body field-type-text-with-summary field-label-hidden',
#   2),
#  ('sanitized_html+entry', 2),
#  ('sanitized_html+ajR', 2),
#  ('sanitized_html+contentText', 2),
#  ('sanitized_html+text smartbody parbase section', 2),
#  ('sanitized_html+aligncenter', 2),
#  ('sanitized_html+_5pbx userContent', 2),
#  ('sanitized_html+subscriber-preview', 2),
#  ('sanitized_html+TSLN-TSLN Body copy', 2),
#  ('sanitized_html+article-paragraph p-22', 2),
#  ('sanitized_html+dropcap', 2),
#  ('sanitized_html+stream-item-header', 2),
#  ('sanitized_html+textBodyBlack', 2),
#  ('sanitized_html+p3 subhead', 2),
#  ('sanitized_html+headline-kicker', 2),
#  ('sanitized_html+shsParagraph1', 2),
#  ('sanitized_html+postoni-header postoni-header-small light-black padB10 lh09em marT0',
#   2),
#  ('sanitized_html+text-align-right', 2),
#  ('sanitized_html+s1', 2),
#  ('sanitized_html+wysiwyg_content', 2),
#  ('sanitized_html+shsParagraph7', 2),
#  ('sanitized_html+podcast-image', 2),
#  ('sanitized_html+m_-6868620953563807351gmail-p2', 2),
#  ('sanitized_html+corpo-conteudo', 2),
#  ('sanitized_html+p2 body-el-text standard-body-el-text', 2),
#  ('sanitized_html+STND-STND BodyText', 2),
#  ('sanitized_html+ReadMoreContentSeparator', 2),
#  ('sanitized_html+contentItem__subhead contentItem__subhead--shortstop', 2),
#  ('sanitized_html+htmlElement', 2),
#  ('sanitized_html+article-body-text component ', 2),
#  ('sanitized_html+p p17', 2),
#  ('sanitized_html+m_-3029486438984178051MsoPlainText', 2),
#  ('sanitized_html+ent-note-title', 2),
#  ('sanitized_html+ent-note-body', 2),
#  ('sanitized_html+m5876080128965914838gmail-msonospacing', 2),
#  ('ar-wikitude', 2),
#  ('sanitized_html+u', 2),
#  ('sanitized_html+wapo_photo_img', 2),
#  ('sanitized_html+x_WordSection1', 2),
#  ('sanitized_html+zn-body__paragraph speakable', 2),
#  ('sanitized_html+gmail-msoplaintext', 2),
#  ('sanitized_html+hugin', 2),
#  ('sanitized_html+x_gmail-interstitial-link', 2),
#  ('sanitized_html+related-links', 1),
#  ('sanitized_html+article-video border-top padding-top padding-bottom margin-bottom flipboard-remove',
#   1),
#  ('sanitized_html+jpt', 1),
#  ('sanitized_html+heading heading3 padding-bottom-2', 1),
#  ('sanitized_html+heading heading3 padding-bottom-5 padding-top border-top',
#   1),
#  ('sanitized_html+padding-bottom', 1),
#  ('sanitized_html+specialred', 1),
#  ('sanitized_html+explainer-link', 1),
#  ('sanitized_html+ss-promo-map-jpt', 1),
#  ('sanitized_html+ss-promo-map-jpt shotspotter-how', 1),
#  ('sanitized_html+quizcontainer ss-promo-map-jpt', 1),
#  ('sanitized_html+elect', 1),
#  ('sanitized_html+wealth-map-jpt', 1),
#  ('sanitized_html+heading heading2', 1),
#  ('sanitized_html+article-video border-top padding-top padding-bottom margin-bottom photo-wrapper',
#   1),
#  ('sanitized_html+article-video margin-bottom photo-wrapper', 1),
#  ('sanitized_html+shorthed', 1),
#  ('sanitized_html+Description', 1),
#  ('sanitized_html+”note”', 1),
#  ('sanitized_html+embedwidget', 1),
#  ('sanitized_html+left', 1),
#  ('sanitized_html+right', 1),
#  ('sanitized_html+graphic-wordpress jpt cf', 1),
#  ('sanitized_html+rail', 1),
#  ('sanitized_html+inline_jpt', 1),
#  ('sanitized_html+kmap-themes', 1),
#  ('sanitized_html+credits', 1),
#  ('sanitized_html+bottom', 1),
#  ('sanitized_html+gallerystory linked', 1),
#  ('sanitized_html+twitter-moment', 1),
#  ('sanitized_html+last-line dialogue', 1),
#  ('sanitized_html+intro-words', 1),
#  ('sanitized_html+sectionLimited', 1),
#  ('sanitized_html+use-of-force-promo', 1),
#  ('sanitized_html+button', 1),
#  ('sanitized_html+drop-cap:first-letter', 1),
#  ('sanitized_html+smallgraphic', 1),
#  ('sanitized_html+g-graphic_container', 1),
#  ('sanitized_html+“sub"', 1),
#  ('sanitized_html+k', 1),
#  ('sanitized_html+first-paragraph ', 1),
#  ('sanitized_html+not-inline', 1),
#  ('sanitized_html+chatter', 1),
#  ('sanitized_html+embed-graphic', 1),
#  ('sanitized_html+embed-ai2html-graphic', 1),
#  ('sanitized_html+pg-contrib', 1),
#  ('sanitized_html+awayline', 1),
#  ('sanitized_html+hide-footer', 1),
#  ('sanitized_html+mceTemp', 1),
#  ('sanitized_html+”caption”', 1),
#  ('sanitized_html+tt', 1),
#  ('sanitized_html+fieldset', 1),
#  ('sanitized_html+size-medium wp-image-2879', 1),
#  ('sanitized_html+size-medium wp-image-3119', 1),
#  ('sanitized_html+padding-top', 1),
#  ('sanitized_html+size-medium wp-image-995', 1),
#  ('sanitized_html+size-medium wp-image-4820', 1),
#  ('sanitized_html+size-medium wp-image-5066', 1),
#  ('sanitized_html+size-medium wp-image-1886', 1),
#  ('sanitized_html+mceWPmore', 1),
#  ('sanitized_html+size-medium wp-image-5926', 1),
#  ('sanitized_html+size-medium wp-image-5803', 1),
#  ('sanitized_html+size-medium wp-image-7841', 1),
#  ('sanitized_html+right padding-top', 1),
#  ('sanitized_html+no-margin no-padding', 1),
#  ('sanitized_html+size-medium wp-image-57852', 1),
#  ('sanitized_html+size-medium wp-image-11132', 1),
#  ('sanitized_html+twitter-mention-button', 1),
#  ('sanitized_html+size-medium wp-image-3350', 1),
#  ('sanitized_html+uiStreamMessage userContentWrapper', 1),
#  ('sanitized_html+size-medium wp-image-11843', 1),
#  ('sanitized_html+daily-figure', 1),
#  ('sanitized_html+size-medium wp-image-8385', 1),
#  ('sanitized_html+size-medium wp-image-12308', 1),
#  ('sanitized_html+visually_embed_cycle', 1),
#  ('sanitized_html+code', 1),
#  ('sanitized_html+size-medium wp-image-12575', 1),
#  ('sanitized_html+size-thumbnail wp-image-12631', 1),
#  ('sanitized_html+size-medium wp-image-12776', 1),
#  ('sanitized_html+size-medium wp-image-12917', 1),
#  ('sanitized_html+size-medium wp-image-13571', 1),
#  ('sanitized_html+size-medium wp-image-13723', 1),
#  ('sanitized_html+size-medium wp-image-13796', 1),
#  ('sanitized_html+posttv-video-embed', 1),
#  ('sanitized_html+size-medium wp-image-8029', 1),
#  ('sanitized_html+size-medium wp-image-8029 ', 1),
#  ('sanitized_html+ wp-image-7314 ', 1),
#  ('sanitized_html+size-medium wp-image-775', 1),
#  ('sanitized_html+size-medium wp-image-773 ', 1),
#  ('sanitized_html+size-medium wp-image-17014', 1),
#  ('sanitized_html+size-medium wp-image-17040', 1),
#  ('sanitized_html+size-medium wp-image-17526', 1),
#  ('sanitized_html+skype_c2c_text_span', 1),
#  ('sanitized_html+size-medium wp-image-17632', 1),
#  ('sanitized_html+size-medium wp-image-20313', 1),
#  ('sanitized_html+size-medium wp-image-18897', 1),
#  ('sanitized_html+size-medium wp-image-20621', 1),
#  ('sanitized_html+size-medium wp-image-20612', 1),
#  ('sanitized_html+size-large wp-image-20615', 1),
#  ('sanitized_html+ wp-image-12183 ', 1),
#  ('sanitized_html+view', 1),
#  ('sanitized_html+size-medium wp-image-22104', 1),
#  ('sanitized_html+size-thumbnail wp-image-22909', 1),
#  ('sanitized_html+eewidget', 1),
#  ('sanitized_html+size-medium wp-image-23574', 1),
#  ('sanitized_html+size-medium wp-image-23571', 1),
#  ('sanitized_html+size-medium wp-image-25365', 1),
#  ('sanitized_html+md', 1),
#  ('sanitized_html+size-medium wp-image-25837', 1),
#  ('sanitized_html+post-title', 1),
#  ('sanitized_html+entry-title pf-title', 1),
#  ('sanitized_html+size-large wp-image-12110', 1),
#  ('sanitized_html+size-medium wp-image-25957', 1),
#  ('sanitized_html+next-in story-content', 1),
#  ('sanitized_html+size-medium wp-image-32546', 1),
#  ('sanitized_html+articleSideAd', 1),
#  ('sanitized_html+spx_inspected_extr spx_global', 1),
#  ('sanitized_html+size-medium wp-image-27838', 1),
#  ('sanitized_html+display hover', 1),
#  ('sanitized_html+size-medium wp-image-23905', 1),
#  ('sanitized_html+styled', 1),
#  ('sanitized_html+cnn_storypgraphtxt cnn_storypgraph16', 1),
#  ('sanitized_html+size-thumbnail wp-image-30649', 1),
#  ('sanitized_html+size-thumbnail wp-image-30652', 1),
#  ('sanitized_html+table_data_list', 1),
#  ('sanitized_html+separator', 1),
#  ('sanitized_html+text parbase text-38 section', 1),
#  ('sanitized_html+zoomMe', 1),
#  ('sanitized_html+size-medium wp-image-32438', 1),
#  ('sanitized_html+wp-image-10002', 1),
#  ('sanitized_html+wp-image-96826', 1),
#  ('sanitized_html+stack6', 1),
#  ('sanitized_html+bar', 1),
#  ('sanitized_html+wp-image-16837 aligncenter', 1),
#  ('sanitized_html+snippet', 1),
#  ('sanitized_html+status cf left', 1),
#  ('sanitized_html+section2', 1),
#  ('sanitized_html+ff2', 1),
#  ('sanitized_html+blurb ', 1),
#  ('sanitized_html+cnn_storypgraphtxt cnn_storypgraph17', 1),
#  ('sanitized_html+msgText', 1),
#  ('sanitized_html+postContent fsm fwn fcg', 1),
#  ('sanitized_html+display', 1),
#  ('sanitized_html+title subhead', 1),
#  ('sanitized_html+wp-inline-bb pb-centered-bb has-subscribe-promo', 1),
#  ('sanitized_html+source', 1),
#  ('sanitized_html+infuse', 1),
#  ('sanitized_html+article_text', 1),
#  ('sanitized_html+postoni subhead', 1),
#  ('sanitized_html+postoni text-center', 1),
#  ('sanitized_html+bc-image', 1),
#  ('sanitized_html+answerAttachmentList', 1),
#  ('sanitized_html+wp-image-17226 aligncenter', 1),
#  ('sanitized_html+co_paragraph', 1),
#  ('sanitized_html+wp-caption-text', 1),
#  ('sanitized_html+ProfileTweet-text js-tweet-text u-dir', 1),
#  ('sanitized_html+t1', 1),
#  ('sanitized_html+cnn_storypgraphtxt cnn_storypgraph31', 1),
#  ('sanitized_html+\\"blockquote\\"', 1),
#  ('sanitized_html+tablepress tablepress-id-16', 1),
#  ('sanitized_html+advert', 1),
#  ('sanitized_html+yt subhead', 1),
#  ('sanitized_html+watch-title long-title', 1),
#  ('sanitized_html+mod-baltsunarticletext mod-articletext', 1),
#  ('sanitized_html+s2', 1),
#  ('sanitized_html+ember-view ad-location', 1),
#  ('sanitized_html+dm-content clearfix', 1),
#  ('sanitized_html+gameId text-muted', 1),
#  ('sanitized_html+wp-image-115613 aligncenter', 1),
#  ('sanitized_html+no-left', 1),
#  ('sanitized_html+h-container', 1),
#  ('sanitized_html+media-mod img-container alignright inline-core-image', 1),
#  ('sanitized_html+postingtitle', 1),
#  ('sanitized_html+data-h3', 1),
#  ('sanitized_html+data-h4', 1),
#  ('sanitized_html+wp-image-55737 aligncenter', 1),
#  ('sanitized_html+field-item even', 1),
#  ('sanitized_html+peeps-button', 1),
#  ('sanitized_html+QuoteMessage', 1),
#  ('sanitized_html+table table-bordered table-striped', 1),
#  ('sanitized_html+wp-image-58156 aligncenter', 1),
#  ('sanitized_html+wp-image-59144 aligncenter', 1),
#  ('sanitized_html+size-medium wp-image-32832', 1),
#  ('sanitized_html+simple_form subscription-form email-form', 1),
#  ('sanitized_html+article-firstGraf', 1),
#  ('sanitized_html+ember-view subhead', 1),
#  ('sanitized_html+postList', 1),
#  ('sanitized_html+less_space', 1),
#  ('sanitized_html+story-asset oembed-asset', 1),
#  ('sanitized_html+sCaption', 1),
#  ('sanitized_html+normal1', 1),
#  ('sanitized_html+custom-video-wrapper posrel clearfix', 1),
#  ('sanitized_html+fbPhotosPhotoCaption', 1),
#  ('sanitized_html+a6S', 1),
#  ('sanitized_html+quoted', 1),
#  ('sanitized_html+fares franklin', 1),
#  ('sanitized_html+BODY_COPY', 1),
#  ('sanitized_html+ParagraphIndented', 1),
#  ('sanitized_html+Argus-Courier-Bodytext, justified_ID', 1),
#  ('sanitized_html+l-content l-nav-padding', 1),
#  ('sanitized_html+main', 1),
#  ('sanitized_html+inline inline-photo float-l', 1),
#  ('sanitized_html+gbl-wrp-2', 1),
#  ('sanitized_html+content-body', 1),
#  ('sanitized_html+myTable', 1),
#  ('sanitized_html+custom-wage-table', 1),
#  ('sanitized_html+posrel', 1),
#  ('sanitized_html+highlight', 1),
#  ('sanitized_html+art-txt', 1),
#  ('sanitized_html+ratingPoints', 1),
#  ('sanitized_html+meta', 1),
#  ('sanitized_html+article-wrapper clearfix', 1),
#  ('sanitized_html+ wp-image-10714', 1),
#  ('sanitized_html+newsrelease', 1),
#  ('sanitized_html+mtm _5pco', 1),
#  ('sanitized_html+ap_para ap_para-9bf7aa2f91f146d7aaeb7f63e8be1255 entry-content',
#   1),
#  ('sanitized_html+ wp-image-12306', 1),
#  ('sanitized_html+ wp-image-12322', 1),
#  ('sanitized_html+table-striped', 1),
#  ('sanitized_html+dropcap in-text', 1),
#  ('sanitized_html+videoInStoryC story-feature', 1),
#  ('sanitized_html+cnnImgChngr', 1),
#  ('sanitized_html+text combinedtext parbase section', 1),
#  ('sanitized_html+photo-booth-header', 1),
#  ('sanitized_html+tile-user-info clearfix', 1),
#  ('sanitized_html+premium-image', 1),
#  ('sanitized_html+text-11 text parbase section', 1),
#  ('sanitized_html+byline', 1),
#  ('sanitized_html+author-flyout george-a-king-iii', 1),
#  ('sanitized_html+text text-14 parbase section', 1),
#  ('sanitized_html+articleBody', 1),
#  ('sanitized_html+article_body', 1),
#  ('sanitized_html+g-aiPstyle0', 1),
#  ('sanitized_html+story-continued', 1),
#  ('sanitized_html+x_hide-in-mobile', 1),
#  ('sanitized_html+a3s', 1),
#  ('sanitized_html+story ', 1),
#  ('sanitized_html+tt-container inread ', 1),
#  ('sanitized_html+detail', 1),
#  ('sanitized_html+hei14', 1),
#  ('sanitized_html+span7', 1),
#  ('sanitized_html+story-description', 1),
#  ('sanitized_html+ wp-image-25144', 1),
#  ('sanitized_html+headlineContent', 1),
#  ('sanitized_html+im', 1),
#  ('sanitized_html+moat-trackable pb-f-theme-normal pb-3 pb-feature pb-layout-item pb-f-article-article-topper',
#   1),
#  ('sanitized_html+Tweet-text e-entry-title', 1),
#  ('sanitized_html+table cb-vertical-top', 1),
#  ('sanitized_html+currentHitHighlight', 1),
#  ('sanitized_html+js-xd-read-more-toggle-view read-more__toggle-view', 1),
#  ('sanitized_html+subnav-arrow', 1),
#  ('sanitized_html+trb_ar_sponsoredmod', 1),
#  ('sanitized_html+djs-d-fig', 1),
#  ('sanitized_html+djs-d-data', 1),
#  ('sanitized_html+article-footer', 1),
#  ('sanitized_html+adL', 1),
#  ('sanitized_html+utilities-bar-wrapper ', 1),
#  ('sanitized_html+newsletter-inline-unit container', 1),
#  ('sanitized_html+p402_hide', 1),
#  ('sanitized_html+pgH1 pgHeadline--wKicker', 1),
#  ('sanitized_html+message_content ', 1),
#  ('sanitized_html+field field-name-body field-type-text-with-summary field-label-hidden entry-content',
#   1),
#  ('sanitized_html+field field-name-field-cinesport field-type-text-long field-label-hidden',
#   1),
#  ('sanitized_html+p402_premium', 1),
#  ('sanitized_html+twitter-video tw-align-center', 1),
#  ('sanitized_html+_pe_o2', 1),
#  ('sanitized_html+story-list-story row item', 1),
#  ('sanitized_html+wrapper', 1),
#  ('sanitized_html+align-right ', 1),
#  ('sanitized_html+story-body', 1),
#  ('sanitized_html+story-asset embed-asset', 1),
#  ('sanitized_html+newsletter-inline-unit container test', 1),
#  ('sanitized_html+ProfileTweet-action ProfileTweet-action--favorite js-toggleState',
#   1),
#  ('sanitized_html+x_p6', 1),
#  ('sanitized_html+x_p2', 1),
#  ('sanitized_html+rteContent', 1),
#  ('sanitized_html+article-paragraph p-36', 1),
#  ('sanitized_html+pb-author-bio', 1),
#  ('sanitized_html+recipeImageCredit', 1),
#  ('sanitized_html+copy_only', 1),
#  ('sanitized_html+page-inner', 1),
#  ('sanitized_html+ygrps-yiv-117648780MsoNormal', 1),
#  ('sanitized_html+attachment_title', 1),
#  ('sanitized_html+tweet', 1),
#  ('sanitized_html+x_layout__inner', 1),
#  ('sanitized_html+note-button', 1),
#  ('sanitized_html+x_paragraph', 1),
#  ('sanitized_html+gallery-row', 1),
#  ('sanitized_html+disc', 1),
#  ('sanitized_html+textLayer', 1),
#  ('sanitized_html+wsj-snippet-body', 1),
#  ('sanitized_html+teads-ui-components-label', 1),
#  ('sanitized_html+PermalinkOverlay-modal', 1),
#  ('sanitized_html+mail-message-header spacer', 1),
#  ('sanitized_html+content-inner', 1),
#  ('sanitized_html+brandconnect-inline-wrapper', 1),
#  ('sanitized_html+m_first-letter', 1),
#  ('sanitized_html+ug_page', 1),
#  ('sanitized_html+body drop-cap', 1),
#  ('sanitized_html+kl', 1),
#  ('sanitized_html+ob-in-page', 1),
#  ('sanitized_html+s14', 1),
#  ('sanitized_html+story-related', 1),
#  ('sanitized_html+story-bodyintroduction', 1),
#  ('sanitized_html+ fpNewsPlayer gb_skip', 1),
#  ('sanitized_html+m_-1381332827882197021wordsection1', 1),
#  ('sanitized_html+tk TmwRj Sn GjkoZd', 1),
#  ('sanitized_html+TweetTextSize TweetTextSize--26px js-tweet-text tweet-text',
#   1),
#  ('sanitized_html+tncms-region ', 1),
#  ('sanitized_html+content-wrp', 1),
#  ('sanitized_html+ad-300', 1),
#  ('sanitized_html+headline small normal-style text-align-inherit subhead', 1),
#  ('sanitized_html+x_dummy', 1),
#  ('sanitized_html+border-bottom-none', 1),
#  ('sanitized_html+articleBodyText section', 1),
#  ('sanitized_html+x_gmail-MsoNoSpacing', 1),
#  ('sanitized_html+newsletter-inline-unit keywordExists', 1),
#  ('sanitized_html+supplemental-items', 1),
#  ('sanitized_html+graf graf--p graf-after--p graf--trailing', 1),
#  ('sanitized_html+article-body__attribution nine digital pty ltd', 1),
#  ('sanitized_html+gmail-MsoPlainText', 1),
#  ('sanitized_html+pg-headline', 1),
#  ('sanitized_html+story-label-explainer arrow_box', 1),
#  ('sanitized_html+s3', 1),
#  ('sanitized_html+defunded-list', 1),
#  ('sanitized_html+pkg', 1),
#  ('sanitized_html+xsm-p', 1),
#  ('sanitized_html+sticky-enabled', 1),
#  ('sanitized_html+anglerfish-image', 1),
#  ('sanitized_html+body-text__p', 1),
#  ('sanitized_html+bucket-description', 1),
#  ('sanitized_html+sm-tile-caption ', 1),
#  ('sanitized_html+story-thumbnail-wrapper', 1),
#  ('sanitized_html+overlay-blurb', 1),
#  ('sanitized_html+trb_ar', 1),
#  ('sanitized_html+TweetTextSize TweetTextSize--normal js-tweet-text tweet-text',
#   1),
#  ('sanitized_html+aside-ad-hdr', 1),
#  ('sanitized_html+ent-photo-caption-float', 1),
#  ('sanitized_html+et_quote_text', 1),
#  ('sanitized_html+et_quote_annot', 1),
#  ('sanitized_html+m_4337387646678002461MsoNoSpacing', 1),
#  ('sanitized_html+ent-photo-caption ent-photo-caption-floated', 1),
#  ('sanitized_html+ndn_embed', 1),
#  ('sanitized_html+m-3848424861795438034gmail-msonospacing', 1),
#  ('sanitized_html+ent-photo-caption-below', 1),
#  ('sanitized_html+el__leafmedia el__leafmedia--speakable-paragraph', 1),
#  ('sanitized_html+x_xmsonormal', 1),
#  ('sanitized_html+js-pagination-panel', 1),
#  ('sanitized_html+wls-paragraph', 1),
#  ('sanitized_html+posttv-video-embed powa powa-processed small', 1),
#  ('sanitized_html+_rp_f', 1),
#  ('sanitized_html+pg-h3', 1),
#  ('sanitized_html+story-body story-body-2', 1),
#  ('sanitized_html+translationCont content display_record_abstract_copy ', 1),
#  ('sanitized_html+_7oe', 1),
#  ('sanitized_html+_5mfr _47e3', 1),
#  ('sanitized_html+wp-caption-dd', 1),
#  ('sanitized_html+graf graf--p graf--startsWithDoubleQuote graf-after--p', 1),
#  ('sanitized_html+ent-related-links-title', 1),
#  ('sanitized_html+outstream-video-ad-dummy', 1),
#  ('sanitized_html+content__segment', 1),
#  ('sanitized_html+flex-play-art', 1),
#  ('sanitized_html+article-author__desc t_body t_body--article', 1),
#  ('sanitized_html+border-bottom- border-bottom- nl-top-hairline', 1),
#  ('sanitized_html+pg-h1', 1),
#  ('sanitized_html+element element-rich-link element--thumbnail element-rich-link--upgraded',
#   1),
#  ('sanitized_html+SandboxRoot env-bp-350', 1),
#  ('sanitized_html+wapo_graphic_img', 1),
#  ('sanitized_html+pb-feed-description', 1),
#  ('sanitized_html+data', 1),
#  ('animated_video', 1),
#  ('sanitized_html+sortable', 1),
#  ('sanitized_html+post-51251 post type-post status-publish format-standard hentry category-education-reform category-teach-for-america',
#   1),
#  ('sanitized_html+size-medium wp-image-11242', 1)]

# %%
pp.pprint(decoded_json['contents'])
# Out:
# [{'content': 'Opinions',
#   'mime': 'text/plain',
#   'section': '/opinions',
#   'type': 'kicker'},
#  {'content': 'The 10 worst things Trump did in 2020',
#   'mime': 'text/plain',
#   'type': 'title'},
#  {'content': 'By Marc Thiessen', 'mime': 'text/plain', 'type': 'byline'},
#  {'content': '2020-12-31T18:39:46.637Z', 'mime': 'text/plain', 'type': 'date'},
#  {'content': 'This week, I offer my <a '
#              'href="https://www.washingtonpost.com/opinions/2019/12/30/worst-things-trump-did/" '
#              'target=_blank>annual </a>lists of the <a '
#              'href="https://www.washingtonpost.com/opinions/2020/12/31/best-things-trump-did-2020/" '
#              'target=_blank>10 best</a> and 10 worst things President Trump '
#              'did this year. Since 2020 was such a horrible year, we’ll start '
#              'with the worst things first:',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': '<b>10. He pardoned war criminals</b>. Trump showed a flagrant '
#              'disregard of the rule of law by <a '
#              'href="https://www.washingtonpost.com/national-security/trump-pardon-blackwater-contractors-iraq/2020/12/22/603da1f4-44b8-11eb-a277-49a6d1f9dff1_story.html" '
#              'target=_blank>pardoning Blackwater contractors</a> who massacred '
#              'unarmed Iraqi civilians, including innocent women and children.',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': '<b>9. He vetoed the bipartisan National Defense Authorization '
#              'Act.</b> Trump vetoed $741 billion in military spending and a 3 '
#              'percent pay raise for our troops over an unrelated issue, and '
#              'put Republicans who voted for it in the difficult position of '
#              'having to choose whether to flip-flop or override his veto.',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': '<b>8. He ordered the drawdown of nearly all U.S. forces in '
#              'Afghanistan and Iraq</b>. Trump was apparently talked out of a '
#              'complete withdrawal, but reducing to <a '
#              'href="https://www.washingtonpost.com/national-security/trump-afghan-war-troop-cuts/2020/11/16/6cc2655c-2827-11eb-b847-66c66ace1afb_story.html" '
#              'target=_blank>2,500 troops</a> in each country makes no '
#              'strategic sense. Despite an ongoing terrorist threat, we will '
#              'have fewer troops in Afghanistan or Iraq than we do in <a '
#              'href="https://www.pewresearch.org/fact-tank/2017/08/22/u-s-active-duty-military-presence-overseas-is-at-its-smallest-in-decades/" '
#              'target=_blank>Spain</a>.',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': '<b>7. He put millions in limbo by threatening to veto '
#              'coronavirus relief.</b> After Democrats refused multiple GOP '
#              'offers since July, Congress finally approved an aid package just '
#              'as much pandemic relief was expiring. But Trump refused to sign '
#              'the bill for almost a week — forcing millions of Americans to '
#              'spend Christmas wondering whether they would be left to fend for '
#              'themselves during the worst of the pandemic.',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': '<b>6. He failed to ban travel from Europe in January</b>. Trump '
#              '<a '
#              'href="https://www.washingtonpost.com/health/trumps-strong-wall-to-block-covid-19-from-china-had-holes/2020/07/04/48061dc2-bdff-11ea-97c1-6cf116ffe26c_story.html" '
#              'target="_blank">announced </a>a travel ban on Jan. 31 on '
#              'non-U.S. residents who had recently been in mainland China, '
#              'saving countless lives. But he did not shut down travel from '
#              'Europe until <a '
#              'href="https://www.nytimes.com/2020/03/12/world/europe/trump-travel-ban-coronavirus.html" '
#              'target="_blank">March 11</a> — almost six weeks later — because '
#              'of objections from his economic advisers. The outbreak in New '
#              'York was <a '
#              'href="https://www.nytimes.com/2020/04/08/science/new-york-coronavirus-cases-europe-genomes.html">seeded '
#              'by travelers from Italy</a>, and New York then seeded the rest '
#              'of the country, becoming <a '
#              'href="https://www.nytimes.com/2020/04/08/science/new-york-coronavirus-cases-europe-genomes.html" '
#              'target="_blank">the primary source of new infections across the '
#              'United States</a>.',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': '<b>5. His jarring fights with reporters during coronavirus '
#              'briefings alienated rather than united us. </b>Trump proudly '
#              'compared his press briefings to a <a '
#              'href="https://www.washingtonpost.com/elections/interactive/2020/trump-pandemic-coronavirus-election/">Mike '
#              'Tyson boxing match</a>, but frightened Americans didn’t want a '
#              'boxing match; they wanted information and reassurance. In '
#              'mid-March, 50.6 percent <a '
#              'href="https://www.realclearpolitics.com/epolls/other/public_approval_of_president_trumps_handling_of_the_coronavirus-7088.html" '
#              'target=_blank>approved</a> of Trump’s handling of the pandemic, '
#              'but by April, he lost the American people — and never recovered.',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': '<b>4. His reluctance to embrace masks cost lives</b>. His '
#              'refusal to require masks at his Tulsa rally, the maskless '
#              'superspreader event at the White House to announce Amy Coney '
#              'Barrett’s Supreme Court nomination, and the scene of him '
#              'dramatically <a '
#              'href="https://www.washingtonpost.com/nation/2020/10/06/trump-coronavirus-mask-doctors/" '
#              'target=_blank>removing his mask</a> on the White House balcony '
#              'after returning from Walter Reed all became symbols of his covid '
#              'response failures.',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': '<b>3. He is failing to distribute more than half the available '
#              'doses of vaccine</b>. His administration is <a '
#              'href="https://www.washingtonpost.com/opinions/2020/12/24/trump-administration-is-holding-back-over-half-its-vaccine-doses-distribute-them-now/">undermining '
#              'the success of Operation Warp Speed</a> by distributing only '
#              'about 18 million doses this year when about <a '
#              'href="https://www.marketwatch.com/story/officials-plan-to-distribute-6-4-million-covid-19-vaccine-doses-in-december-aiming-for-40-million-doses-by-end-of-year-11606251786" '
#              'target="_blank">40 million will be available</a> — leaving about '
#              '22 million Americans without any immunity during the deadliest '
#              'period since the pandemic began.',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': '<b>2. He lost a winnable election and then refused to accept the '
#              'results — or his own responsibility for losing.</b> Trump lost '
#              'because he alienated millions who approved of his policies but '
#              'were tired of chaos. His mocking of Joe Biden’s cognitive '
#              'struggles offended seniors, and their support for Trump <a '
#              'href="https://www.cnn.com/election/2020/exit-polls/president/arizona" '
#              'target=_blank>declined</a> by <a '
#              'href="https://www.cnn.com/election/2016/results/exit-polls/arizona/president" '
#              'target=_blank>five points</a> in Arizona and <a '
#              'href="https://www.cnn.com/election/2016/results/exit-polls/georgia/president" '
#              'target=_blank>11 points</a> in <a '
#              'href="https://www.cnn.com/election/2020/exit-polls/president/georgia" '
#              'target=_blank>Georgia</a> compared with 2016. And after winning '
#              '<a '
#              'href="https://www.foxnews.com/politics/voter-analysis-bidens-path-presidency" '
#              'target=_blank>suburban voters</a> by two points in 2016, he lost '
#              'them by 10 this year. If he had performed with these groups the '
#              'way he did four years ago, no amount of real or imagined fraud '
#              'could have deprived him of a second term.',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': '<b>1. He discussed imposing martial law at an Oval Office '
#              'meeting</b>. The suggestion by Michael Flynn that Trump declare '
#              'martial law and use the military to re-run the election in swing '
#              'states is insane. That Trump took it seriously enough to <a '
#              'href="https://www.washingtonpost.com/politics/trump-assembles-a-ragtag-crew-of-conspiracy-minded-allies-in-flailing-bid-to-reverse-election-loss/2020/12/21/d7674cd2-43b2-11eb-b0e4-0f182923a025_story.html">discuss</a> '
#              'it in the Oval Office is shameful, as are his calls for elected '
#              'Republicans to overturn the results.',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': 'Finally, one of the worst things Trump did is not on the list '
#              'because the results are not yet in: He has barely lifted a '
#              'finger in Georgia to save Republican control of the Senate. He '
#              'is so focused on overturning the presidential election that he '
#              'could very well hand Democrats control of the Senate on Jan. 5 — '
#              'and with it, unchecked power to reverse his achievements and '
#              'enact a radical agenda. If that happens, Trump will leave the '
#              'White House in infamy.',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': 'That is the worst list of worsts I have compiled in four years. '
#              'But 2020 also saw some of the greatest accomplishments of '
#              'Trump’s presidency. Does the good outweigh the bad? <a '
#              'href="https://www.washingtonpost.com/opinions/2020/12/31/best-things-trump-did-2020/" '
#              'target=_blank>Here’s my next column, reviewing</a> the 10 best '
#              'things Trump did in 2020.',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': '<b>Watch Opinions videos: </b>',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': '<b>Read more from Marc A. Thiessen:</b>',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': '<a '
#              'href="https://www.washingtonpost.com/opinions/2019/12/30/worst-things-trump-did/" '
#              'target=_blank>The 10 worst things Trump did in 2019</a>',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': '<a '
#              'href="https://www.washingtonpost.com/opinions/2019/12/26/best-things-trump-has-done/" '
#              'target=_blank>The 10 best things Trump did in 2019</a>',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': '<a '
#              'href="https://www.washingtonpost.com/opinions/the-10-worst-things-trump-did-in-2018/2019/01/02/f4025456-0eb0-11e9-84fc-d58c33d6c8c7_story.html?tid=lk_inline_manual_24&itid=lk_inline_manual_29">The '
#              '10 worst things Trump did in 2018</a>',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': '<a '
#              'href="https://www.washingtonpost.com/opinions/the-10-best-things-trump-has-done-in-2018/2018/12/31/a2de64b6-0d1b-11e9-84fc-d58c33d6c8c7_story.html?itid=lk_inline_manual_28">The '
#              '10 best things Trump did in 2018</a>',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': '<a '
#              'href="https://www.washingtonpost.com/opinions/the-10-worst-things-trump-has-done-in-his-first-year-in-office/2017/12/29/2446d9f6-eca8-11e7-b698-91d4e35920a3_story.html" '
#              'target=_blank>The 10 worst things Trump did in his first year in '
#              'office</a>',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'},
#  {'content': '<a '
#              'href="https://www.washingtonpost.com/opinions/the-10-best-things-trump-has-done-in-his-first-year-in-office/2017/12/27/c79ce93c-ea7e-11e7-9f92-10a2203f6c8d_story.html" '
#              'target=_blank>The 10 best things Trump did in his first year in '
#              'office</a>',
#   'mime': 'text/html',
#   'subtype': 'paragraph',
#   'type': 'sanitized_html'}]

# %% [markdown]
# Notes:
# * Only top-level attributes that appear in every article are `id`, `article_url`, `title`, `author` and `contents`. Therefore `contents` attribute should be used (instead of `content`) when performing text mining.
# * There are two top-level date attributes (denoting publishing date of the article): `publish_date` and `published_date`. Neither appears in every article and should be picked whichever is available, if needed.
# * Only content pieces of type `sanitized_html` will be mined, specificly of subtypes `paragraph`, `correction`, `blockquote` and `p1`, based on prevalence and inspection.

# %% [markdown]
# ### Testing out text extraction

# %%
def is_rel_type_subtype(contents_obj):
    relevant_subtypes = ['paragraph', 'correction', 'blockquote', 'p1']
    return (contents_obj["type"] == "sanitized_html" and 
            contents_obj["subtype"] in relevant_subtypes)

def extract_plaintext(contents):
    raw_html_pieces = [obj["content"] for obj in contents if is_rel_type_subtype(obj)]
    document = '\n'.join(raw_html_pieces)
    raw_text = re.sub(r'<.*?>', '', document)
    return raw_text

# %%
# decoded_json is a free variable
print(extract_plaintext(decoded_json['contents']))
# Out:
# This week, I offer my annual lists of the 10 best and 10 worst things President Trump did this year. Since 2020 was such a horrible year, we’ll start with the worst things first:
# 10. He pardoned war criminals. Trump showed a flagrant disregard of the rule of law by pardoning Blackwater contractors who massacred unarmed Iraqi civilians, including innocent women and children.
# 9. He vetoed the bipartisan National Defense Authorization Act. Trump vetoed $741 billion in military spending and a 3 percent pay raise for our troops over an unrelated issue, and put Republicans who voted for it in the difficult position of having to choose whether to flip-flop or override his veto.
# 8. He ordered the drawdown of nearly all U.S. forces in Afghanistan and Iraq. Trump was apparently talked out of a complete withdrawal, but reducing to 2,500 troops in each country makes no strategic sense. Despite an ongoing terrorist threat, we will have fewer troops in Afghanistan or Iraq than we do in Spain.
# 7. He put millions in limbo by threatening to veto coronavirus relief. After Democrats refused multiple GOP offers since July, Congress finally approved an aid package just as much pandemic relief was expiring. But Trump refused to sign the bill for almost a week — forcing millions of Americans to spend Christmas wondering whether they would be left to fend for themselves during the worst of the pandemic.
# 6. He failed to ban travel from Europe in January. Trump announced a travel ban on Jan. 31 on non-U.S. residents who had recently been in mainland China, saving countless lives. But he did not shut down travel from Europe until March 11 — almost six weeks later — because of objections from his economic advisers. The outbreak in New York was seeded by travelers from Italy, and New York then seeded the rest of the country, becoming the primary source of new infections across the United States.
# 5. His jarring fights with reporters during coronavirus briefings alienated rather than united us. Trump proudly compared his press briefings to a Mike Tyson boxing match, but frightened Americans didn’t want a boxing match; they wanted information and reassurance. In mid-March, 50.6 percent approved of Trump’s handling of the pandemic, but by April, he lost the American people — and never recovered.
# 4. His reluctance to embrace masks cost lives. His refusal to require masks at his Tulsa rally, the maskless superspreader event at the White House to announce Amy Coney Barrett’s Supreme Court nomination, and the scene of him dramatically removing his mask on the White House balcony after returning from Walter Reed all became symbols of his covid response failures.
# 3. He is failing to distribute more than half the available doses of vaccine. His administration is undermining the success of Operation Warp Speed by distributing only about 18 million doses this year when about 40 million will be available — leaving about 22 million Americans without any immunity during the deadliest period since the pandemic began.
# 2. He lost a winnable election and then refused to accept the results — or his own responsibility for losing. Trump lost because he alienated millions who approved of his policies but were tired of chaos. His mocking of Joe Biden’s cognitive struggles offended seniors, and their support for Trump declined by five points in Arizona and 11 points in Georgia compared with 2016. And after winning suburban voters by two points in 2016, he lost them by 10 this year. If he had performed with these groups the way he did four years ago, no amount of real or imagined fraud could have deprived him of a second term.
# 1. He discussed imposing martial law at an Oval Office meeting. The suggestion by Michael Flynn that Trump declare martial law and use the military to re-run the election in swing states is insane. That Trump took it seriously enough to discuss it in the Oval Office is shameful, as are his calls for elected Republicans to overturn the results.
# Finally, one of the worst things Trump did is not on the list because the results are not yet in: He has barely lifted a finger in Georgia to save Republican control of the Senate. He is so focused on overturning the presidential election that he could very well hand Democrats control of the Senate on Jan. 5 — and with it, unchecked power to reverse his achievements and enact a radical agenda. If that happens, Trump will leave the White House in infamy.
# That is the worst list of worsts I have compiled in four years. But 2020 also saw some of the greatest accomplishments of Trump’s presidency. Does the good outweigh the bad? Here’s my next column, reviewing the 10 best things Trump did in 2020.
# Watch Opinions videos:
# Read more from Marc A. Thiessen:
# The 10 worst things Trump did in 2019
# The 10 best things Trump did in 2019
# The 10 worst things Trump did in 2018
# The 10 best things Trump did in 2018
# The 10 worst things Trump did in his first year in office
# The 10 best things Trump did in his first year in office
