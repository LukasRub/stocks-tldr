# %% [markdown]
# #### Imports

# %%
import re
import json
from pathlib import Path

import numpy as np
import pandas as pd
import scipy.stats
import pytrec_eval

from IPython.display import display


QRELS_PATH = "../../data/test/doc2vec/qrels.txt"
RUN_FILE_PATHS = list(Path("../../data/test/doc2vec/").glob("**/run_files/*.txt"))

# %% [markdown]
# #### Functions

# %%
def get_vector_size(index):
    match = re.search("d\d+", index)
    return int(match.group()[1:])


def get_negative_samples(index):
    match = re.search("n\d+", index)
    return int(match.group()[1:])


def get_window_size(index):
    match = re.search("w\d+", index)
    return int(match.group()[1:])


def get_epochs(index):
    match = re.search("ep\d+", index)
    return int(match.group()[2:])


def get_ratio(index):
    match = re.search("(?:r\()(.*)(?:\))", index)
    return float(match.group(1))

    
def get_stategy(index):
    return index.split(".")[-1]


def filter_irrelevant_columns(df, suffixes=["_100", "_200", "_500", "_1000"]):
    is_irrelevant = lambda x: any([x.endswith(suffix) for suffix in suffixes])
    cols_to_drop = [col for col in df.columns if is_irrelevant(col)]
    return df.drop(columns=cols_to_drop)


def infer_columns(df):
    # Vector size
    df["vector_size"] = df.index.map(get_vector_size)
    df["ns"] = df.index.map(get_negative_samples)
    df["w"] = df.index.map(get_window_size)
    df["epochs"] = df.index.map(get_epochs)
    df["ratio"] = df.index.map(get_ratio)
    df["strategy"] = df.index.map(get_stategy)
    df = filter_irrelevant_columns(df)
    
    return df


def read_qrels(qrels_path=QRELS_PATH):
    with open(QRELS_PATH, "r") as fp:
        qrels = pytrec_eval.parse_qrel(fp)
    return qrels


def read_runfiles(runfile_paths=RUN_FILE_PATHS, pattern=None):
    if pattern:
        relevant_runfiles = [p for p in runfile_paths if pattern in str(p)]
    else:
        relevant_runfiles = runfile_paths
        
    runs = dict()
    
    for run_file in relevant_runfiles:
        run_id = run_file.stem
        with open(run_file, "r") as fp:
            run = pytrec_eval.parse_run(fp)
        runs[run_id] = run   
        
    return runs
    
    
def evaluate(qrels, runs, measures):
    run_results_by_query = dict()
    run_results = dict()
    for run_id, run in runs.items():
        evaluator = pytrec_eval.RelevanceEvaluator(qrels, measures)
        results = evaluator.evaluate(run)       
        mean_results = {measure: np.mean([v[measure] for _, v in results.items()]) 
                        for measure in results["0"].keys()}
        run_results_by_query[run_id] = results
        run_results[run_id] = mean_results

    return run_results_by_query, run_results

# %% [markdown]
# ### Reading qrels and listing supported evaluation measures

# %%
qrels = read_qrels()

# %% [markdown]
# ### Inspecting results (by run)

# %%
# pattern = "r(0.8).full"
pattern = None
runs = read_runfiles(pattern=pattern)
run_results_by_query, run_results = evaluate(qrels, runs, ["map", "ndcg"])

results_df = infer_columns(pd.DataFrame(run_results).T)
results_df = results_df.sort_values("ndcg", ascending=False)

pd.set_option("max_rows", 3000)
display(results_df)
# Out:
#                                                          map      ndcg  \
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.690265  0.815255
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.688167  0.814401
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.682708  0.810531
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.682688  0.810502
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.685134  0.810450
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.684920  0.806648
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.682093  0.806227
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.691488  0.805743
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.694341  0.805709
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.690096  0.805269
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.680879  0.804543
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.676528  0.803834
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.688281  0.803327
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.670277  0.802286
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.673462  0.802014
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.689935  0.801636
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.682938  0.801389
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.672959  0.801136
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.672027  0.800951
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.669600  0.800899
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.685031  0.800412
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.669183  0.800254
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.685963  0.799574
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.678249  0.799158
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...  0.672834  0.798997
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.676915  0.798271
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.677361  0.798055
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.672337  0.797597
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.672142  0.797485
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.673611  0.797228
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.672838  0.797076
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...  0.668790  0.796639
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.677901  0.796398
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.687293  0.795240
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.667484  0.795017
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.684354  0.794806
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.672224  0.794338
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...  0.669828  0.794188
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...  0.667791  0.794155
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...  0.660674  0.793346
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...  0.660863  0.793338
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...  0.660143  0.793106
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...  0.669805  0.792846
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40...  0.646164  0.792668
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...  0.658578  0.791227
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.684001  0.790807
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40...  0.649834  0.790786
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40...  0.640285  0.790236
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.676457  0.789988
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.674173  0.789579
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.671124  0.788881
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.675542  0.788837
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...  0.659573  0.788650
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...  0.656236  0.788092
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40...  0.650276  0.787333
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.673325  0.786760
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40...  0.635932  0.785498
# run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20...  0.645018  0.785468
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...  0.665921  0.785270
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40...  0.638448  0.785241
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.675442  0.784460
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40...  0.636768  0.783653
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.661629  0.782839
# run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20...  0.633714  0.780897
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.665353  0.780151
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40...  0.651846  0.780080
# run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20...  0.633313  0.779993
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.665272  0.779947
# run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20...  0.634262  0.779752
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.663869  0.779648
# run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20...  0.631994  0.779510
# run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20...  0.635108  0.779419
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.662421  0.779362
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.663496  0.779139
# run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20...  0.631638  0.778667
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...  0.656305  0.778665
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.662775  0.778581
# run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20...  0.628078  0.776343
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.656868  0.776087
# run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20...  0.631356  0.775415
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.663693  0.775324
# run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20...  0.635810  0.774644
# run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20...  0.642289  0.774606
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40...  0.650056  0.774319
# run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20...  0.648410  0.773966
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20...  0.628198  0.773853
# run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20...  0.639346  0.773705
# run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20...  0.625678  0.773553
# run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20...  0.642589  0.773407
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.668944  0.773343
# run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20...  0.626244  0.772846
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40...  0.639280  0.772533
# run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20...  0.621548  0.772266
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20...  0.625556  0.771944
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40...  0.635454  0.771663
# run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20...  0.645585  0.771495
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.646469  0.771282
# run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20...  0.648146  0.771170
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.662909  0.771079
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.647310  0.771025
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20...  0.633251  0.770765
# run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20...  0.636285  0.770709
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...  0.638249  0.770504
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20...  0.631545  0.770454
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.641514  0.770414
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.643791  0.770240
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40...  0.641960  0.770213
# run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20...  0.629336  0.769964
# run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20...  0.645878  0.769760
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.642281  0.769577
# run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20...  0.625156  0.769153
# run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20...  0.626475  0.769052
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...  0.635759  0.768711
# run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20...  0.615679  0.768693
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20...  0.623737  0.768682
# run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20...  0.623990  0.768532
# run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20...  0.631696  0.768529
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20...  0.619824  0.768437
# run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20...  0.641443  0.768258
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...  0.651217  0.768192
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...  0.651100  0.768130
# run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20...  0.626711  0.768121
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...  0.636267  0.768120
# run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20...  0.622464  0.767718
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20...  0.633908  0.767679
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.656825  0.767490
# run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20...  0.630425  0.767471
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20...  0.626737  0.767304
# run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20...  0.626716  0.767288
# run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20...  0.636254  0.766998
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40...  0.638030  0.766987
# run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20...  0.629713  0.766912
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20...  0.631955  0.766825
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40...  0.629011  0.766806
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...  0.649857  0.766613
# run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20...  0.638466  0.766482
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20...  0.616315  0.766407
# run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20...  0.627136  0.766104
# run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20...  0.623727  0.766091
# run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20...  0.629029  0.766079
# run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20...  0.633431  0.765981
# run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20...  0.638596  0.765967
# run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20...  0.621115  0.765959
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20...  0.630195  0.765663
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.612383  0.765439
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.655638  0.765422
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20...  0.633130  0.765188
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20...  0.629034  0.765107
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40...  0.623642  0.764924
# run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20...  0.629804  0.764743
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.654400  0.764566
# run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20...  0.635429  0.764542
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.605643  0.764467
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...  0.633450  0.764233
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20...  0.631089  0.763863
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40...  0.618526  0.763810
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...  0.634844  0.763210
# run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20...  0.640658  0.762124
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.617488  0.762085
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...  0.626199  0.762047
# run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20...  0.623059  0.761640
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...  0.624264  0.761552
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20...  0.640330  0.761348
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...  0.625120  0.761220
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40...  0.614359  0.761129
# run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20...  0.640100  0.761059
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...  0.619005  0.761056
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40...  0.618748  0.760916
# run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20...  0.619424  0.760734
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20...  0.631461  0.760704
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40...  0.634525  0.760638
# run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20...  0.618061  0.760595
# run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20...  0.610059  0.760593
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20...  0.633980  0.760486
# run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20...  0.607229  0.760264
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...  0.614837  0.760262
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.652430  0.760226
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.656473  0.759745
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...  0.620349  0.759304
# run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20...  0.612670  0.758996
# run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20...  0.625114  0.758820
# run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20...  0.632747  0.758756
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.648480  0.758555
# run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20...  0.597766  0.757522
# run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20...  0.635897  0.757477
# run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20...  0.621770  0.757371
# run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20...  0.627841  0.757140
# run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20...  0.625781  0.757042
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...  0.618203  0.756822
# run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20...  0.615111  0.756808
# run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20...  0.633966  0.756679
# run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20...  0.607929  0.756557
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...  0.633951  0.756502
# run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20...  0.637539  0.755868
# run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20...  0.602313  0.755846
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.593299  0.755746
# run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20...  0.639881  0.755606
# run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20...  0.617803  0.755576
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.591665  0.755177
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...  0.609277  0.755083
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20...  0.637859  0.755005
# run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20...  0.634781  0.754825
# run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20...  0.622084  0.754533
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.613661  0.754491
# run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20...  0.621399  0.754412
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.588605  0.754296
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...  0.607404  0.754277
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.586161  0.754226
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...  0.635383  0.754161
# run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20...  0.596497  0.754117
# run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20...  0.638767  0.753497
# run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20...  0.618930  0.753434
# run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20...  0.626267  0.753111
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.645182  0.752957
# run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20...  0.613134  0.752880
# run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20...  0.622120  0.752757
# run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20...  0.616428  0.752746
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.583652  0.752740
# run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20...  0.622911  0.752611
# run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20...  0.586070  0.752559
# run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20...  0.619022  0.752381
# run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20...  0.620498  0.752285
# run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20...  0.616730  0.752179
# run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20...  0.604086  0.752152
# run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20...  0.633226  0.751903
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...  0.622233  0.751902
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.637136  0.751771
# run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20...  0.633268  0.751213
# run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20...  0.622409  0.751182
# run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20...  0.596522  0.751057
# run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20...  0.592122  0.751000
# run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20...  0.633777  0.750965
# run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20...  0.597875  0.750875
# run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20...  0.582445  0.750827
# run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20...  0.579523  0.749990
# run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20...  0.625446  0.749652
# run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20...  0.605839  0.749567
# run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20...  0.615424  0.749530
# run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20...  0.608751  0.749186
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...  0.577028  0.748392
# run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20...  0.588305  0.748067
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.638124  0.747806
# run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20...  0.595153  0.747769
# run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20...  0.593929  0.747673
# run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20...  0.587114  0.747465
# run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20...  0.601418  0.747423
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...  0.628853  0.747324
# run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20...  0.612388  0.747255
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.614413  0.747166
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.605375  0.747063
# run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20...  0.578460  0.746845
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.597879  0.746664
# run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20...  0.584977  0.746525
# run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20...  0.580369  0.746169
# run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20...  0.581058  0.746113
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...  0.612254  0.745907
# run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20...  0.603772  0.745743
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.617097  0.745670
# run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20...  0.599883  0.745573
# run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20...  0.575380  0.745515
# run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20...  0.579805  0.745380
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.600396  0.745303
# run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20...  0.577410  0.745287
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...  0.588153  0.745251
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.604556  0.744910
# run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20...  0.619149  0.744810
# run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20...  0.591116  0.744803
# run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20...  0.590462  0.744792
# run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20...  0.619172  0.744607
# run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20...  0.587378  0.744512
# run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20...  0.598215  0.744455
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...  0.569707  0.744416
# run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20...  0.596950  0.744078
# run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20...  0.603523  0.744023
# run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20...  0.580532  0.743961
# run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20...  0.599631  0.743492
# run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20...  0.592261  0.743415
# run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20...  0.584887  0.743164
# run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20...  0.593235  0.743133
# run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20...  0.584691  0.742977
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40...  0.616463  0.742854
# run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20...  0.590814  0.742635
# run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20...  0.597276  0.742602
# run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20...  0.598828  0.742511
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...  0.565744  0.742475
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.599185  0.742448
# run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20...  0.583580  0.742200
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...  0.603147  0.742070
# run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20...  0.586081  0.742052
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...  0.592348  0.741994
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.636174  0.741954
# run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20...  0.581818  0.741908
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.589737  0.741779
# run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20...  0.580219  0.741638
# run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20...  0.575074  0.741534
# run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20...  0.576057  0.741504
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...  0.576959  0.741127
# run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20...  0.598809  0.741084
# run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20...  0.585542  0.741066
# run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20...  0.578488  0.740932
# run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20...  0.589275  0.740609
# run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20...  0.588679  0.740465
# run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20...  0.593471  0.740450
# run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20...  0.582208  0.740271
# run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20...  0.580788  0.740239
# run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20...  0.622629  0.740237
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20...  0.616597  0.740163
# run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20...  0.595240  0.740073
# run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20...  0.566742  0.739782
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...  0.562439  0.739700
# run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20...  0.608187  0.739693
# run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20...  0.589465  0.739613
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...  0.596595  0.739356
# run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20...  0.627040  0.739335
# run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20...  0.588465  0.739177
# run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20...  0.621759  0.739078
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...  0.598538  0.738893
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...  0.595920  0.738623
# run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20...  0.568782  0.738578
# run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20...  0.586251  0.738284
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.622212  0.738178
# run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20...  0.569283  0.738117
# run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20...  0.591077  0.738111
# run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20...  0.584967  0.738066
# run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20...  0.572543  0.737948
# run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20...  0.573419  0.737840
# run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20...  0.573840  0.737626
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.602293  0.737580
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.585560  0.737496
# run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20...  0.575566  0.737296
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.609882  0.737114
# run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20...  0.587707  0.737024
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.593900  0.736971
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.603873  0.736952
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.579163  0.736652
# run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20...  0.599667  0.736434
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.625476  0.736321
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...  0.600467  0.736169
# run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20...  0.588930  0.736055
# run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20...  0.596764  0.735806
# run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20...  0.613359  0.735743
# run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20...  0.564671  0.735616
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.625797  0.735596
# run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20...  0.593201  0.735569
# run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20...  0.619385  0.735540
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.595413  0.735471
# run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20...  0.591281  0.735441
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...  0.593616  0.735294
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40...  0.614271  0.735214
# run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20...  0.578687  0.734967
# run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20...  0.596839  0.734894
# run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20...  0.595631  0.734845
# run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20...  0.562396  0.734787
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.584944  0.734709
# run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20...  0.559013  0.734660
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.572806  0.734660
# run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20...  0.581930  0.734620
# run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20...  0.581063  0.734545
# run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20...  0.594674  0.734467
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...  0.555930  0.734395
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.587902  0.734339
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.591403  0.734324
# run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20...  0.556197  0.734303
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...  0.618335  0.734298
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.582465  0.734148
# run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20...  0.591320  0.734119
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.569823  0.734077
# run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20...  0.581065  0.734052
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...  0.595277  0.734017
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.596835  0.733946
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.581901  0.733653
# run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20...  0.595188  0.733651
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...  0.594556  0.733105
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20...  0.615599  0.732977
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.625243  0.732939
# run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20...  0.577668  0.732910
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.578186  0.732897
# run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20...  0.609805  0.732783
# run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20...  0.587870  0.732641
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...  0.599552  0.732638
# run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20...  0.576191  0.732628
# run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20...  0.588625  0.732581
# run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20...  0.586223  0.732539
# run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20...  0.566564  0.732430
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...  0.609768  0.732426
# run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20...  0.598512  0.732332
# run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20...  0.579396  0.732326
# run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20...  0.565001  0.732319
# run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20...  0.597801  0.732316
# run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20...  0.554786  0.732296
# run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20...  0.551974  0.732245
# run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20...  0.591229  0.732123
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.612388  0.731929
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.620002  0.731874
# run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20...  0.587256  0.731696
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.629260  0.731555
# run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20...  0.550296  0.731531
# run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20...  0.554251  0.731349
# run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20...  0.586819  0.731296
# run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20...  0.563548  0.731217
# run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20...  0.552644  0.730966
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.563226  0.730956
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.591954  0.730946
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.585693  0.730823
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.587026  0.730712
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.574301  0.730703
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...  0.580164  0.730596
# run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20...  0.603414  0.730410
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.576148  0.730348
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.602991  0.730272
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...  0.589879  0.730178
# run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20...  0.593087  0.730157
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.587548  0.729930
# run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20...  0.576658  0.729899
# run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20...  0.599201  0.729852
# run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20...  0.583950  0.729762
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.590545  0.729711
# run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20...  0.561570  0.729707
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.581692  0.729597
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.598761  0.729555
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...  0.580080  0.729552
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.580105  0.729537
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.605238  0.729513
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...  0.578286  0.729463
# run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20...  0.614552  0.729435
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20...  0.603486  0.729387
# run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20...  0.590335  0.729356
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40...  0.599318  0.729252
# run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20...  0.585335  0.729096
# run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20...  0.607253  0.729085
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...  0.586992  0.728973
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...  0.583792  0.728957
# run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20...  0.565908  0.728884
# run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20...  0.579605  0.728825
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...  0.596493  0.728793
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...  0.568618  0.728697
# run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20...  0.569925  0.728662
# run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20...  0.578550  0.728662
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.591562  0.728647
# run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20...  0.569265  0.728425
# run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20...  0.590495  0.728412
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.580322  0.728329
# run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20...  0.561912  0.728249
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.557947  0.728121
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.600400  0.728034
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...  0.592675  0.728016
# run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20...  0.577731  0.727857
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.593211  0.727827
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.608140  0.727690
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...  0.589130  0.727621
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.617100  0.727609
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...  0.590690  0.727539
# run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20...  0.565175  0.727446
# run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20...  0.559790  0.727325
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...  0.599320  0.727306
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...  0.579645  0.727191
# run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20...  0.569795  0.726917
# run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20...  0.596222  0.726909
# run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20...  0.586347  0.726797
# run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20...  0.565219  0.726703
# run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20...  0.562080  0.726510
# run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20...  0.595060  0.726490
# run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20...  0.592237  0.726246
# run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20...  0.599908  0.726180
# run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20...  0.598503  0.726129
# run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20...  0.556613  0.725627
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.615493  0.725574
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.577299  0.725485
# run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20...  0.611006  0.725362
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.609801  0.725359
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.597865  0.725234
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.602733  0.725204
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.582007  0.725111
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.551703  0.725082
# run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20...  0.556575  0.724407
# run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20...  0.541730  0.724225
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...  0.586956  0.723878
# run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20...  0.544677  0.723605
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.588336  0.723552
# run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20...  0.594479  0.723482
# run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20...  0.539516  0.723184
# run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20...  0.595590  0.723068
# run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20...  0.585256  0.723038
# run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20...  0.573305  0.722266
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.566594  0.722198
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.574326  0.721944
# run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20...  0.573598  0.721899
# run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20...  0.558445  0.721831
# run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20...  0.581507  0.721765
# run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20...  0.570815  0.721465
# run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20...  0.536039  0.721449
# run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20...  0.591482  0.721319
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.575201  0.721283
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...  0.577212  0.721257
# run.Doc2Vec(dm-c,d300,n20,w5,mc5,s1e-05,t8,ep20...  0.572699  0.720925
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.589439  0.720919
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.602311  0.720912
# run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20...  0.610902  0.720910
# run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20...  0.555117  0.720884
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.581625  0.720795
# run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20...  0.560703  0.720774
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.612299  0.720678
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.574052  0.720563
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.575957  0.720491
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...  0.564883  0.720349
# run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20...  0.553144  0.720349
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.585663  0.720308
# run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20...  0.586108  0.720168
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...  0.585694  0.720135
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20...  0.596042  0.720059
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.575083  0.719893
# run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20...  0.586432  0.719888
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...  0.578103  0.719765
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.582212  0.719671
# run.Doc2Vec(dm-c,d300,n20,w5,mc5,s1e-05,t8,ep20...  0.581826  0.719658
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.593349  0.719521
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...  0.568921  0.719421
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.617673  0.719377
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.603361  0.719142
# run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20...  0.572591  0.719126
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.570061  0.719067
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...  0.574660  0.719061
# run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20...  0.561361  0.719051
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...  0.565312  0.718988
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.593332  0.718796
# run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20...  0.537459  0.718637
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...  0.577927  0.718434
# run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20...  0.558692  0.718397
# run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20...  0.574917  0.718375
# run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20...  0.550645  0.718360
# run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20...  0.584929  0.718350
# run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20...  0.564543  0.718291
# run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20...  0.587527  0.718072
# run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20...  0.559635  0.717932
# run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20...  0.530093  0.717764
# run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20...  0.550339  0.717640
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...  0.590637  0.717625
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.570994  0.717350
# run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20...  0.584604  0.717331
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...  0.584778  0.717165
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.587967  0.717077
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.599198  0.717018
# run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20...  0.556773  0.716961
# run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20...  0.562523  0.716954
# run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20...  0.550717  0.716899
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40...  0.588603  0.716817
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.605199  0.716802
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...  0.559353  0.716796
# run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20...  0.550527  0.716703
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.568087  0.716561
# run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20...  0.553128  0.716543
# run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20...  0.592330  0.716458
# run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20...  0.563567  0.716086
# run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20...  0.552845  0.716049
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.575756  0.716048
# run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20...  0.576612  0.715948
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40...  0.589521  0.715683
# run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20...  0.530959  0.715619
# run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20...  0.593956  0.715567
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.584676  0.715430
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.603879  0.715379
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20...  0.570807  0.715348
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...  0.586993  0.714991
# run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20...  0.548658  0.714956
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40...  0.596605  0.714792
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40...  0.586575  0.714630
# run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20...  0.573762  0.714493
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.601147  0.714396
# run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20...  0.575161  0.714194
# run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20...  0.585109  0.713989
# run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20...  0.560801  0.713976
# run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20...  0.549084  0.713955
# run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20...  0.598762  0.713946
# run.Doc2Vec(dm-c,d300,n20,w5,mc5,s1e-05,t8,ep20...  0.557533  0.713859
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.563390  0.713828
# run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20...  0.578503  0.713771
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.585716  0.713573
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...  0.570512  0.713546
# run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20...  0.561276  0.713482
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...  0.543507  0.713396
# run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20...  0.559998  0.713352
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40...  0.583555  0.713349
# run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20...  0.545297  0.713314
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...  0.583714  0.712974
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...  0.550685  0.712858
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...  0.585666  0.712730
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...  0.601659  0.712687
# run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20...  0.565209  0.712614
# run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20...  0.561475  0.712602
# run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20...  0.554017  0.712209
# run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20...  0.552171  0.711752
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...  0.590740  0.711663
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...  0.551087  0.711637
# run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20...  0.554911  0.711510
# run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20...  0.572796  0.711500
# run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20...  0.571313  0.711467
# run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20...  0.552916  0.711361
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...  0.558477  0.711230
# run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20...  0.570557  0.711077
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20...  0.547157  0.711037
# run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20...  0.552499  0.710807
# run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20...  0.596624  0.710602
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...  0.579466  0.710469
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...  0.540947  0.710344
# run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20...  0.562951  0.710278
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...  0.543729  0.710111
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...  0.603865  0.710060
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...  0.545317  0.709827
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...  0.558277  0.709674
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20...  0.550915  0.709564
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.584080  0.709552
# run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20...  0.543887  0.709544
# run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20...  0.532433  0.709529
# run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20...  0.559846  0.709456
# run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20...  0.552997  0.709455
# run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20...  0.547219  0.709388
# run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20...  0.548727  0.709274
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...  0.583562  0.709159
# run.Doc2Vec(dm-c,d300,n20,w5,mc5,s1e-05,t8,ep20...  0.563725  0.709041
# run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20...  0.579576  0.709021
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40...  0.560464  0.708891
# run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20...  0.579524  0.708824
# run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20...  0.563980  0.708823
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40...  0.577275  0.708773
# run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20...  0.532145  0.708514
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...  0.558294  0.708481
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20...  0.546134  0.708428
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...  0.593822  0.708384
# run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20...  0.553364  0.708378
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20...  0.583073  0.708312
# run.Doc2Vec(dm-c,d300,n20,w5,mc5,s1e-05,t8,ep20...  0.566401  0.708309
# run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20...  0.584809  0.708156
# run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20...  0.548506  0.708131
# run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20...  0.580591  0.707987
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20...  0.583415  0.707821
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...  0.596150  0.707780
# run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20...  0.562555  0.707748
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...  0.584278  0.707683
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20...  0.574059  0.707610
# run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20...  0.591408  0.707579
# run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20...  0.578599  0.707552
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40...  0.563209  0.707238
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20...  0.578399  0.707173
# run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20...  0.560694  0.707102
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...  0.574507  0.707086
# run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20...  0.541713  0.707070
# run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20...  0.578629  0.706973
# ...
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...      20   0.70  summary
# run.Doc2Vec(dm-c,d300,n20,w5,mc5,s1e-05,t8,ep20...      20   0.90  summary
# run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20...      20   0.10  summary
# run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20...      20   0.95  summary
# run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20...      20   1.00  summary
# run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20...      20   0.05     full
# run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20...      20   0.95  summary
# run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20...      20   0.85  summary
# run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20...      20   0.05     full
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...      20   0.05     full
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...      20   0.05     full
# run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20...      20   0.05     full
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...      20   0.20  summary
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...      20   0.85  summary
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...      20   0.15  summary
# run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20...      20   0.60  summary
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...      20   0.00     full
# run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20)...      20   0.00  summary
# run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d300,n20,w5,mc5,s1e-05,t8,ep20...      20   0.80  summary
# run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...      20   0.15  summary
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20...      20   0.10     full
# run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20...      20   0.60  summary
# run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20...      20   0.80  summary
# run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20...      20   0.10  summary
# run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20...      20   0.05     full
# run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20...      20   0.90  summary
# run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20...      20   0.10  summary
# run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20...      20   0.80  summary
# run.Doc2Vec(dm-c,d300,n20,w5,mc5,s1e-05,t8,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d300,n20,w5,mc5,s1e-05,t8,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...      20   0.05     full
# run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20...      20   0.05     full
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20...      20   0.85  summary
# run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20...      20   0.90  summary
# run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...      20   0.05     full
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...      20   0.90  summary
# run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20...      20   0.85  summary
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...      20   0.10  summary
# run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20...      20   0.05     full
# run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20...      20   0.05     full
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20...      20   0.10  summary
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...      20   0.95  summary
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40...      40   0.00  summary
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40...      40   0.00     full
# run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20...      20   0.05     full
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...      20   1.00  summary
# run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20...      20   1.00  summary
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...      20   0.00     full
# run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20)...      20   0.00  summary
# run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20...      20   0.05     full
# run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20...      20   0.70  summary
# run.Doc2Vec(dm-c,d300,n20,w5,mc5,s1e-05,t8,ep20...      20   0.95  summary
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...      20   0.80  summary
# run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20...      20   0.05     full
# run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20...      20   0.95  summary
# run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40...      40   0.00  summary
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40...      40   0.00     full
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...      40   0.00     full
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40...      40   0.00  summary
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20...      20   0.10  summary
# run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20...      20   0.10  summary
# run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20...      20   0.85  summary
# run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20...      20   1.00  summary
# run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...      20   0.85  summary
# run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20...      20   0.10     full
# run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20...      20   0.05     full
# run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20...      20   0.90  summary
# run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...      20   0.00     full
# run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20)...      20   0.00  summary
# run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20...      20   0.05     full
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...      40   0.00  summary
# run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40...      40   0.00     full
# run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20...      20   0.95  summary
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...      20   0.90  summary
# run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20...      20   1.00  summary
# run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...      20   0.05  summary
# run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20...      20   0.90  summary
# run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20...      20   0.95  summary
# run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20...      20   0.70  summary
# run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20...      20   0.80  summary
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...      20   0.10  summary
# run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...      20   0.05     full
# run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...      20   0.95  summary
# run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d300,n20,w5,mc5,s1e-05,t8,ep20...      20   1.00  summary
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...      20   0.05     full
# run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20...      20   0.95  summary
# run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20...      20   0.05     full
# run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20...      20   1.00  summary
# run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...      20   1.00  summary
# run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20...      20   0.85  summary
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20...      20   0.80  summary
# run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20...      20   1.00  summary
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...      20   0.05  summary
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20...      20   0.05     full
# run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20...      20   0.85  summary
# run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20...      20   0.70  summary
# run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20...      20   0.90  summary
# run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...      20   0.00     full
# run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20)...      20   0.00  summary
# run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20...      20   0.95  summary
# run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20...      20   0.90  summary
# run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20...      20   1.00  summary
# run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20...      20   0.80  summary
# run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20...      20   0.95  summary
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20...      20   1.00  summary
# run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20...      20   0.00  summary
# run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20...      20   0.00     full
# run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20...      20   0.85  summary
# run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20...      20   0.90  summary
# run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20...      20   0.95  summary
# run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20...      20   1.00  summary

# %% [markdown]
# ### Inspecting results (by query)

# %%
res_query = run_results_by_query
res = [res_query[run] for run in res_query.keys()]
res_query_df = pd.DataFrame.from_dict(res[0], orient="index")

for i in range(1, len(res)):
    res_query_df += pd.DataFrame.from_dict(res[i], orient="index")

res_query_df = filter_irrelevant_columns(res_query_df / len(res))
res_query_df = res_query_df.sort_values("ndcg")

print("Queries with lowest average ndcg")
display(res_query_df.head(10))
print("Queries with highest average ndcg")
display(res_query_df.tail(10))

# %% [markdown]
# ### Significance testing

# %%
def test_significance(run_1, run_2, measure, test_f):
    query_ids = list(qrels.keys())
    first_scores = [run_results_by_query[run_1][query_id][measure] for query_id in query_ids]
    second_scores = [run_results_by_query[run_2][query_id][measure] for query_id in query_ids]
    return test_f(first_scores, second_scores)

# %% [markdown]
# **Vector dimensionality (everything else static):**
# * `d100` -> `d150` not significant
# * `d100` -> `d200`, `d300` significant
#
# Conclusions this far: best models should have vector dimensionality `d100` or `d150`
#
# **Negative sampling:**
# * (for `d100`) `n20` -> `n10` not significant for `w1`, `w2`, `w3`, significant for `w4`, `w5`
# * (for `d150`) `n20` -> `n10` not significant for all window sizes except for `w4`
#
# Conclusions this far: best models should have vector dimensionality `d100` and negative sampling value of `n20` with window sizes `w1`, `w2`, `w3`
#
# **Window size:**
# * (for `d100`, `n20`) `w1` -> `w2` not significant, `w1` -> `w3`, `w4`, `w5` significant
#
# Conclusions this far: best models should have vector dimensionality `d100` and negative sampling value of `n20` with window sizes `w1`, `w2`
#
# **Epochs**
# Only four models were trained with `e40`:
# * `Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40)`
# * `Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40)`
# * `Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40)`
# * `Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40)`
#
# Significance tests showed insignificant differences in perfomance between these models and their counterparts trained with 20 epochs

# %%
first_run = "run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40).r(0.8).full"
second_run = "run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20).r(0.8).full"

# first_run = results_df.index[0]
# second_run = results_df.index[-1]

display(results_df.loc[first_run])
display(results_df.loc[second_run])

test_significance(first_run, second_run, "ndcg", scipy.stats.ttest_rel)
# Out:
# map            0.646164
# ndcg           0.792668
# vector_size         100
# ns                   20
# w                     3
# epochs               40
# ratio               0.8
# strategy           full
# Name: run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40).r(0.8).full, dtype: object
# map            0.629034
# ndcg           0.765107
# vector_size         100
# ns                   20
# w                     3
# epochs               20
# ratio               0.8
# strategy           full
# Name: run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20).r(0.8).full, dtype: object
# Ttest_relResult(statistic=1.5276509332384145, pvalue=0.1327780322212468)

# %%
run_len = len(results_df)
for i in range(1, run_len):
    _, pval = test_significance(results_df.index[0], results_df.index[i], "ndcg", scipy.stats.ttest_rel)
    if (pval < 0.05):
        status_msg = "{:2} {}\t\t{}\t{:.3f}".format(i, results_df.index[i],
                                                    results_df.loc[results_df.index[i], 
                                                    "ndcg"], pval)
        print(status_msg)
# Out:
# 63 run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20).r(0.7).full		0.7808969650705719	0.045
# 66 run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20).r(0.9).full		0.7799926066319288	0.039
# 68 run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20).r(0.85).full		0.7797518356328195	0.045
# 70 run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20).r(1).full		0.7795099836830109	0.042
# 71 run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20).r(0.8).full		0.7794190029650605	0.043
# 74 run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20).r(0.95).full		0.778666743385241	0.039
# 75 run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20).r(0.7).full		0.7786652484699075	0.045
# 77 run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20).r(0.8).full		0.7763434703194092	0.019
# 78 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0.7).full		0.7760873185221426	0.018
# 79 run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20).r(0.6).full		0.7754151835062117	0.026
# 81 run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20).r(0.5).full		0.7746441433638865	0.022
# 82 run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20).r(0.6).full		0.7746058601861384	0.038
# 85 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20).r(0.85).full		0.7738526297804416	0.014
# 86 run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20).r(0.7).full		0.7737045219466144	0.010
# 87 run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20).r(0.9).full		0.7735532018147692	0.010
# 89 run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20).r(0.4).full		0.7733434111912203	0.032
# 90 run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20).r(0.85).full		0.7728461797362555	0.012
# 91 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40).r(0.6).full		0.7725329467557283	0.044
# 92 run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20).r(0.95).full		0.7722662383205671	0.008
# 93 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20).r(0.9).full		0.771944121799765	0.012
# 94 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40).r(0.7).full		0.771663299227739	0.038
# 95 run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20).r(0.5).full		0.7714949234060051	0.032
# 96 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0.85).full		0.7712818174745865	0.006
# 98 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20).r(0.4).full		0.771078819680047	0.046
# 99 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0.8).full		0.7710251874399643	0.006
# 100 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20).r(0.6).full		0.7707651222354559	0.016
# 102 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0.8).full		0.7705039024061369	0.005
# 103 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20).r(0.7).full		0.7704541788517945	0.012
# 104 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(1).full		0.7704136726950165	0.003
# 105 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0.9).full		0.7702396370243336	0.005
# 106 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40).r(0.5).full		0.7702127255423329	0.041
# 107 run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20).r(0.8).full		0.7699639869589817	0.008
# 108 run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20).r(0.7).full		0.7697603560285391	0.013
# 109 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0.95).full		0.7695766703466609	0.004
# 110 run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20).r(0.9).full		0.7691530226724902	0.007
# 111 run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20).r(0.85).full		0.7690524931499337	0.007
# 112 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0.7).full		0.7687108657709566	0.008
# 113 run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20).r(1).full		0.7686931052896693	0.004
# 114 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20).r(0.8).full		0.7686818381812535	0.008
# 115 run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20).r(0.95).full		0.7685318170501605	0.006
# 116 run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20).r(0.7).full		0.7685289820932246	0.007
# 117 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20).r(0.95).full		0.7684373701979675	0.009
# 118 run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20).r(0.5).full		0.7682583655641496	0.026
# 119 run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20).r(0.5).full		0.7681920456273007	0.034
# 120 run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20).r(0.6).full		0.7681302886415925	0.029
# 121 run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20).r(0.9).full		0.7681207071656655	0.037
# 122 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0.6).full		0.7681202448583202	0.006
# 123 run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20).r(1).full		0.7677180751574196	0.005
# 124 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20).r(0.95).full		0.7676789162741058	0.015
# 125 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0.6).full		0.7674897182672128	0.010
# 126 run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20).r(0.4).full		0.7674712281086797	0.020
# 127 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20).r(1).full		0.767304424198069	0.014
# 128 run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20).r(0.85).full		0.767287769754751	0.039
# 129 run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20).r(0.7).full		0.7669977723956964	0.016
# 130 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40).r(0.4).full		0.766987460790571	0.031
# 131 run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20).r(1).full		0.7669121494174747	0.007
# 132 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20).r(0.9).full		0.7668246443198179	0.014
# 133 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40).r(0.8).full		0.7668057207604466	0.025
# 134 run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20).r(0.5).full		0.7666127427419812	0.035
# 135 run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20).r(0.6).full		0.7664819081194127	0.017
# 136 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20).r(1).full		0.7664070797895515	0.007
# 137 run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20).r(0.8).full		0.7661042339405276	0.033
# 138 run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20).r(0.95).full		0.7660912037338008	0.032
# 139 run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20).r(0.95).full		0.7660790488220849	0.007
# 140 run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20).r(0.9).full		0.7659813202524781	0.007
# 141 run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20).r(0.8).full		0.765966923418019	0.008
# 142 run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20).r(1).full		0.7659588693414267	0.032
# 143 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20).r(0.85).full		0.765663381235455	0.013
# 144 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0.6).full		0.7654388439306701	0.010
# 146 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20).r(0.5).full		0.7651878187902935	0.008
# 147 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20).r(0.8).full		0.7651074055180013	0.010
# 148 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40).r(0.85).full		0.7649242837703732	0.020
# 149 run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20).r(0.8).full		0.7647425570216156	0.010
# 151 run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20).r(0.85).full		0.7645415525088193	0.007
# 152 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0.7).full		0.7644668877063039	0.006
# 153 run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20).r(0.7).full		0.7642334408676901	0.003
# 154 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20).r(0.7).full		0.763862859986962	0.008
# 155 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40).r(0.95).full		0.7638096085657502	0.016
# 156 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0.5).full		0.7632103967325475	0.008
# 157 run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20).r(0.5).full		0.7621240895491985	0.008
# 158 run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20).r(0.6).summary		0.7620850532787878	0.027
# 159 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0.85).full		0.7620466263232676	0.002
# 160 run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20).r(0.85).full		0.7616395014255417	0.007
# 161 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0.9).full		0.7615522108414899	0.001
# 162 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20).r(0.4).full		0.7613480263832628	0.012
# 163 run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20).r(0.8).full		0.7612196199642484	0.001
# 164 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40).r(1).full		0.7611287007832659	0.010
# 165 run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20).r(0.6).full		0.7610588188600214	0.003
# 166 run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20).r(0.85).full		0.7610561675576046	0.001
# 167 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40).r(0.9).full		0.7609162123522536	0.011
# 168 run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20).r(0.9).full		0.7607335363151021	0.006
# 169 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20).r(0.6).full		0.7607043017854108	0.007
# 170 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40).r(0.3).full		0.7606378443061463	0.034
# 171 run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20).r(0.8).full		0.7605950171842123	0.003
# 172 run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20).r(0.9).full		0.7605930256774094	0.002
# 173 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20).r(0.5).full		0.7604857771613143	0.009
# 174 run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20).r(0.7).full		0.7602640850146987	0.014
# 175 run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20).r(0.9).full		0.7602615290132595	0.001
# 176 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0.5).full		0.7602263000136814	0.005
# 177 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40).r(0.3).full		0.7597445958507669	0.018
# 178 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0.95).full		0.7593044410550179	0.001
# 179 run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20).r(0.85).full		0.7589956809079277	0.002
# 180 run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20).r(0.6).full		0.7588200454080005	0.004
# 181 run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20).r(0.5).full		0.7587558930981928	0.006
# 182 run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20).r(0.4).full		0.7585550568039955	0.034
# 183 run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20).r(0.7).full		0.757522018790522	0.001
# 184 run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20).r(0.4).full		0.757476678360099	0.009
# 185 run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20).r(1).full		0.7573711747774473	0.002
# 186 run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20).r(0.7).full		0.7571404903544956	0.006
# 187 run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20).r(0.8).full		0.7570418150653814	0.005
# 188 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(1).full		0.7568217119727905	0.001
# 189 run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20).r(0.95).full		0.7568075622516824	0.003
# 190 run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20).r(0.6).full		0.7566785167810648	0.007
# 191 run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20).r(1).full		0.7565567775013775	0.003
# 192 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0.4).full		0.7565015119263564	0.005
# 193 run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20).r(0.6).full		0.7558679724661002	0.003
# 194 run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20).r(0.95).full		0.7558464481995743	0.000
# 195 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0.8).full		0.755745716495735	0.001
# 196 run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20).r(0.5).full		0.7556063171587647	0.005
# 197 run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20).r(0.5).full		0.7555757091585941	0.004
# 198 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0.85).full		0.7551772807077276	0.001
# 199 run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20).r(0.95).full		0.7550833931188597	0.000
# 200 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20).r(0.3).full		0.7550047786300164	0.009
# 201 run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20).r(0.4).full		0.7548249299218788	0.008
# 202 run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20).r(0.8).full		0.7545328354866199	0.003
# 203 run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20).r(0.5).summary		0.7544907329644766	0.013
# 204 run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20).r(0.85).full		0.7544119855503767	0.002
# 205 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0.9).full		0.7542957041266674	0.001
# 206 run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20).r(1).full		0.7542765572981707	0.000
# 207 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0.95).full		0.754226041189888	0.001
# 208 run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20).r(0.4).full		0.754160649180652	0.014
# 209 run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20).r(0.8).full		0.7541169271708305	0.006
# 210 run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20).r(0.3).full		0.7534967260623203	0.011
# 211 run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20).r(0.9).full		0.7534344781894424	0.001
# 212 run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20).r(0.7).full		0.7531111482547007	0.003
# 213 run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20).r(0.3).full		0.7529568539276225	0.008
# 214 run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20).r(0.5).full		0.7528802188115047	0.007
# 215 run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20).r(0.85).full		0.7527568439310077	0.002
# 216 run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20).r(0.5).full		0.7527459165109528	0.006
# 217 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(1).full		0.7527401538282755	0.001
# 218 run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20).r(0.4).full		0.7526107374754	0.005
# 219 run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20).r(0.8).full		0.7525594512039577	0.000
# 220 run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20).r(0.95).full		0.7523809436071844	0.001
# 221 run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20).r(0.9).full		0.7522849309826867	0.001
# 222 run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20).r(0.95).full		0.7521791843073556	0.001
# 223 run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20).r(0.7).full		0.752152180359797	0.003
# 224 run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20).r(0.3).full		0.7519026856657749	0.017
# 225 run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20).r(0.6).full		0.7519016946734929	0.001
# 226 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40).r(0.3).full		0.7517713494125365	0.010
# 227 run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20).r(0.4).full		0.7512133124376281	0.005
# 228 run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20).r(0.3).full		0.7511819105750036	0.007
# 229 run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20).r(0.6).full		0.7510573994115555	0.002
# 230 run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20).r(0.7).full		0.7509998496369898	0.005
# 231 run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20).r(0.5).full		0.750965037424425	0.006
# 232 run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20).r(1).full		0.7508745696476591	0.000
# 233 run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20).r(0.85).full		0.7508266231692823	0.000
# 234 run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20).r(0.9).full		0.7499903614714273	0.000
# 235 run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20).r(0.4).full		0.7496516917712104	0.002
# 236 run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20).r(0.6).full		0.7495667121620635	0.006
# 237 run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20).r(0.4).full		0.7495297393027218	0.006
# 238 run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20).r(0.6).full		0.749185982974341	0.003
# 239 run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20).r(0.8).full		0.7483922791044555	0.004
# 240 run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20).r(0.85).full		0.7480670628882167	0.002
# 241 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0.4).full		0.747805727252952	0.003
# 242 run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20).r(0.7).full		0.7477685474472987	0.000
# 243 run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20).r(0.7).full		0.747673435748	0.002
# 244 run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20).r(1).full		0.7474647881187427	0.001
# 245 run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20).r(0.6).full		0.747422902394014	0.001
# 246 run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20).r(0.4).full		0.7473242283367975	0.007
# 247 run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20).r(1).full		0.747254572613219	0.001
# 248 run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20).r(0.5).summary		0.7471657017753728	0.010
# 249 run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20).r(0.7).summary		0.7470630971271628	0.007
# 250 run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20).r(0.95).full		0.7468446820596086	0.003
# 251 run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20).r(0.7).summary		0.7466643485925364	0.006
# 252 run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20).r(0.8).full		0.7465245065366718	0.000
# 253 run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20).r(0.85).full		0.7461692758964612	0.003
# 254 run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20).r(0.8).full		0.7461132295774326	0.003
# 255 run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20).r(0.5).full		0.7459071857194051	0.001
# 256 run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20).r(0.4).full		0.7457425193355152	0.003
# 257 run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20).r(0.4).summary		0.7456697642485073	0.008
# 258 run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20).r(0.6).full		0.745572762091612	0.001
# 259 run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20).r(1).full		0.7455145788541084	0.003
# 260 run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20).r(0.9).full		0.7453802730649606	0.001
# 261 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0.5).full		0.7453034886014207	0.002
# 262 run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20).r(0.9).full		0.7452870731376946	0.003
# 263 run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20).r(0.6).full		0.7452509888508689	0.001
# 264 run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20).r(0.6).summary		0.7449104848519349	0.007
# 265 run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20).r(0.6).full		0.7448104312783054	0.002
# 266 run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20).r(0.6).full		0.7448026022051262	0.003
# 267 run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20).r(0.5).full		0.7447919561714392	0.001
# 268 run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20).r(0.4).full		0.7446065441791402	0.004
# 269 run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20).r(0.8).full		0.7445124612271145	0.001
# 270 run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20).r(0.6).full		0.7444550739169713	0.001
# 271 run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20).r(0.85).full		0.7444159872157127	0.003
# 272 run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20).r(0.8).full		0.7440776737743631	0.002
# 273 run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20).r(0.5).full		0.7440233114729348	0.002
# 274 run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20).r(0.85).full		0.7439608969610473	0.000
# 275 run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20).r(0.6).full		0.7434918743918839	0.002
# 276 run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20).r(0.8).full		0.743415025350258	0.001
# 277 run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20).r(0.85).full		0.7431638918244705	0.000
# 278 run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20).r(0.85).full		0.7431331050850853	0.002
# 279 run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20).r(0.85).full		0.742977496947664	0.001
# 280 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40).r(0.3).full		0.7428542911250281	0.004
# 281 run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20).r(0.7).full		0.7426351210722928	0.000
# 282 run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20).r(0.7).full		0.742602119276574	0.001
# 283 run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20).r(0.5).full		0.7425110595933304	0.001
# 284 run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20).r(0.9).full		0.7424750448125139	0.002
# 285 run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20).r(0.8).summary		0.7424476644749174	0.003
# 286 run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20).r(0.8).full		0.7421996904550905	0.000
# 287 run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20).r(0.8).summary		0.7420695171321354	0.002
# 288 run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20).r(0.9).full		0.7420518311383874	0.001
# 289 run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20).r(0.5).full		0.7419940847361659	0.001
# 290 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0.3).full		0.7419537080114261	0.005
# 291 run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20).r(0.9).full		0.7419075558758222	0.000
# 292 run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20).r(0.8).summary		0.741779466518005	0.004
# 293 run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20).r(0.95).full		0.7416380217904279	0.000
# 294 run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20).r(0.95).full		0.7415337312113164	0.001
# 295 run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20).r(0.95).full		0.7415035959553262	0.001
# 296 run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20).r(0.7).full		0.741127337628577	0.002
# 297 run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20).r(0.4).full		0.7410839640756678	0.001
# 298 run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20).r(0.85).full		0.74106607763027	0.001
# 299 run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20).r(1).full		0.7409318244482417	0.000
# 300 run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20).r(0.9).full		0.7406090638976186	0.002
# 301 run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20).r(0.95).full		0.7404650480655509	0.002
# 302 run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20).r(0.6).full		0.7404504745041346	0.000
# 303 run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20).r(0.95).full		0.7402706482840317	0.001
# 304 run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20).r(0.6).full		0.7402394230873544	0.000
# 305 run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20).r(0.5).full		0.7402369754058907	0.001
# 306 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20).r(0.4).full		0.7401627200946547	0.001
# 307 run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20).r(0.5).full		0.7400733822147652	0.001
# 308 run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20).r(0.85).full		0.7397824239294294	0.000
# 309 run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20).r(0.95).full		0.7397003505534834	0.002
# 310 run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20).r(0.3).full		0.7396932504018754	0.003
# 311 run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20).r(0.8).full		0.7396132970623837	0.001
# 312 run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20).r(0.9).summary		0.7393562866984417	0.001
# 313 run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20).r(0.4).full		0.7393354595180749	0.001
# 314 run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20).r(0.85).full		0.739177158179698	0.001
# 315 run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20).r(0.4).full		0.7390775580144484	0.002
# 316 run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20).r(0.85).summary		0.7388925149755732	0.002
# 317 run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20).r(0.4).full		0.7386229829763358	0.001
# 318 run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20).r(0.8).full		0.7385779314271923	0.000
# 319 run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20).r(0.9).full		0.7382844684750087	0.001
# 320 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40).r(0.5).summary		0.7381779074529291	0.002
# 321 run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20).r(1).full		0.7381174510656889	0.001
# 322 run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20).r(0.5).full		0.7381110172041041	0.001
# 323 run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20).r(1).full		0.7380657976576496	0.001
# 324 run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20).r(0.7).full		0.7379480618838075	0.000
# 325 run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20).r(0.9).full		0.737840245884975	0.000
# 326 run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20).r(0.9).full		0.7376256357582816	0.000
# 327 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0.4).full		0.7375799141218826	0.002
# 328 run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20).r(0.85).summary		0.737495952554836	0.003
# 329 run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20).r(0.7).full		0.7372961574352602	0.000
# 330 run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20).r(0.3).summary		0.7371138040055812	0.005
# 331 run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20).r(0.6).full		0.7370237512107298	0.001
# 332 run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20).r(0.85).summary		0.7369710543947554	0.002
# 333 run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20).r(0.4).summary		0.7369516888819565	0.005
# 334 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20).r(0.7).summary		0.7366524877410878	0.004
# 335 run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20).r(0.3).full		0.7364338929572962	0.004
# 336 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20).r(0.3).full		0.7363208551996657	0.003
# 337 run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20).r(0.5).summary		0.7361687258491943	0.002
# 338 run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20).r(0.5).full		0.7360550193783207	0.000
# 339 run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20).r(0.4).full		0.7358059896261617	0.001
# 340 run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20).r(0.3).full		0.7357426081923256	0.002
# 341 run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20).r(0.8).full		0.7356161602089635	0.001
# 342 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20).r(0.2).full		0.7355962664645543	0.007
# 343 run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20).r(0.4).full		0.7355686705479216	0.001
# 344 run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20).r(0.4).full		0.7355402745985458	0.002
# 345 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40).r(0.85).summary		0.7354709222490422	0.002
# 346 run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20).r(0.7).full		0.735441186351064	0.001
# 347 run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20).r(0.95).summary		0.7352940909490664	0.001
# 348 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40).r(0.2).full		0.7352138436379504	0.006
# 349 run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20).r(0.7).full		0.7349674697828033	0.000
# 350 run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20).r(0.6).full		0.7348940577463676	0.000
# 351 run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20).r(0.4).full		0.7348453938851214	0.001
# 352 run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20).r(0.85).full		0.7347868023338612	0.000
# 353 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0.85).summary		0.7347088381833224	0.000
# 354 run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20).r(0.95).full		0.7346598969404106	0.000
# 355 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20).r(0.8).summary		0.7346597275613141	0.004
# 356 run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20).r(0.95).full		0.7346201992172224	0.000
# 357 run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20).r(1).full		0.7345448903411019	0.000
# 358 run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20).r(0.4).full		0.7344665119554784	0.001
# 359 run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20).r(1).full		0.7343952905997462	0.001
# 360 run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20).r(0.9).summary		0.7343389841925403	0.001
# 361 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40).r(0.9).summary		0.7343244572739427	0.002
# 362 run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20).r(0.9).full		0.734303331819527	0.000
# 363 run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20).r(0.3).full		0.7342979865400624	0.003
# 364 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0.9).summary		0.7341483864496249	0.000
# 365 run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20).r(0.3).full		0.7341186510573883	0.001
# 366 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20).r(0.85).summary		0.7340766116726006	0.003
# 367 run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20).r(0.4).full		0.7340523684340281	0.000
# 368 run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20).r(0.7).summary		0.7340171489511107	0.001
# 369 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20).r(0.3).summary		0.7339458274481062	0.009
# 370 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20).r(0.6).summary		0.7336531714762604	0.004
# 371 run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20).r(0.4).full		0.733651168506199	0.003
# 372 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0.6).summary		0.7331049205683228	0.002
# 373 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20).r(0.2).full		0.7329774949664559	0.001
# 374 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40).r(0.3).summary		0.7329387305718978	0.002
# 375 run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20).r(0.6).full		0.7329097592155763	0.000
# 376 run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20).r(0.9).summary		0.7328965982267491	0.002
# 377 run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20).r(0.3).full		0.7327829079126106	0.002
# 378 run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20).r(0.8).full		0.73264055478821	0.000
# 379 run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20).r(0.4).full		0.7326382246765816	0.001
# 380 run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20).r(0.5).full		0.7326276462053644	0.000
# 381 run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20).r(0.5).full		0.7325805291709873	0.000
# 382 run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20).r(0.5).full		0.7325388357191364	0.000
# 383 run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20).r(0.95).full		0.7324298817360444	0.000
# 384 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0.3).full		0.7324257258050739	0.001
# 385 run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20).r(0.3).full		0.7323320722337865	0.003
# 386 run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20).r(0.7).full		0.732326473857732	0.000
# 387 run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20).r(1).full		0.7323188781032525	0.000
# 388 run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20).r(0.4).full		0.7323155902655777	0.001
# 389 run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20).r(0.7).full		0.7322964381505184	0.000
# 390 run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20).r(0.95).full		0.7322445211506918	0.000
# 391 run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20).r(0.7).full		0.7321225371358407	0.000
# 392 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40).r(0.5).summary		0.731928939081845	0.002
# 393 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40).r(0.4).summary		0.731873920602221	0.001
# 394 run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20).r(0.6).full		0.731695606419697	0.001
# 395 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40).r(0.2).full		0.7315548886481793	0.003
# 396 run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20).r(1).full		0.7315312363216775	0.000
# 397 run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20).r(0.9).full		0.7313488866781666	0.000
# 398 run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20).r(0.3).full		0.73129558352777	0.001
# 399 run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20).r(1).full		0.7312170291198998	0.000
# 400 run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20).r(1).full		0.7309659256980876	0.000
# 401 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20).r(0.9).summary		0.7309558655204991	0.003
# 402 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20).r(0.4).summary		0.7309456932923333	0.004
# 403 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40).r(0.95).summary		0.7308231157511051	0.001
# 404 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0.7).summary		0.7307118232971601	0.001
# 405 run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20).r(0.95).summary		0.7307029025574999	0.001
# 406 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0.95).summary		0.7305964240816807	0.001
# 407 run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20).r(0.2).full		0.7304100179256449	0.003
# 408 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0.95).summary		0.7303482789974183	0.000
# 409 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40).r(0.6).summary		0.7302723672046602	0.002
# 410 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0.7).summary		0.7301780251161873	0.001
# 411 run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20).r(0.5).full		0.7301566154777663	0.001
# 412 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20).r(0.5).summary		0.7299304538060064	0.004
# 413 run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20).r(1).full		0.7298991244658235	0.000
# 414 run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20).r(0.4).full		0.729851738933309	0.002
# 415 run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20).r(0.85).full		0.7297623327465967	0.000
# 416 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40).r(0.8).summary		0.7297110039189509	0.001
# 417 run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20).r(0.6).full		0.7297069455998091	0.000
# 418 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40).r(1).summary		0.7295969092386707	0.001
# 419 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0.3).full		0.7295545035156417	0.001
# 420 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0.9).summary		0.7295522617060635	0.001
# 421 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0.8).summary		0.7295373661037411	0.000
# 422 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20).r(0.5).summary		0.729513117561801	0.002
# 423 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(1).summary		0.7294634599847751	0.001
# 424 run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20).r(0.3).full		0.7294349988875477	0.002
# 425 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20).r(0.3).full		0.7293865138369507	0.001
# 426 run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20).r(0.3).full		0.7293562304606526	0.001
# 427 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40).r(0.2).full		0.7292521361864601	0.002
# 428 run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20).r(0.4).full		0.7290964850396057	0.001
# 429 run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20).r(0.3).full		0.7290850975796638	0.001
# 430 run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20).r(0.3).full		0.7289725867481824	0.001
# 431 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0.8).summary		0.7289568682992391	0.001
# 432 run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20).r(0.5).full		0.7288836219266207	0.000
# 433 run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20).r(0.9).full		0.7288245609658184	0.000
# 434 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0.5).summary		0.728792648457318	0.001
# 435 run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20).r(1).summary		0.7286973047892993	0.001
# 436 run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20).r(0.8).full		0.7286624490610119	0.000
# 437 run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20).r(0.3).full		0.7286615595157002	0.000
# 438 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20).r(0.7).summary		0.7286471947003546	0.001
# 439 run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20).r(0.4).full		0.7284245219215444	0.000
# 440 run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20).r(0.5).summary		0.7284119957549144	0.004
# 441 run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20).r(0.95).summary		0.7283286394412115	0.001
# 442 run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20).r(0.9).full		0.7282487752134927	0.000
# 443 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20).r(0.95).summary		0.7281213904539974	0.002
# 444 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20).r(0.6).summary		0.7280343273864094	0.001
# 445 run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20).r(0.6).summary		0.7280161337413564	0.000
# 446 run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20).r(0.95).full		0.7278568598585237	0.000
# 447 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40).r(0.7).summary		0.7278265286738965	0.001
# 448 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40).r(0.6).summary		0.7276903413619908	0.000
# 449 run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20).r(1).summary		0.7276210075639012	0.000
# 450 run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20).r(0.3).full		0.7276085039555051	0.002
# 451 run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20).r(0.4).summary		0.7275391374724124	0.001
# 452 run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20).r(0.8).full		0.7274457232251094	0.000
# 453 run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20).r(0.95).full		0.7273247675065002	0.000
# 454 run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20).r(0.3).full		0.727306316893502	0.001
# 455 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0.85).summary		0.7271913090881442	0.001
# 456 run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20).r(0.4).full		0.7269170320895272	0.000
# 457 run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20).r(0.4).summary		0.7269092752756033	0.003
# 458 run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20).r(0.5).full		0.726796518991653	0.001
# 459 run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20).r(0.85).full		0.7267032870692022	0.000
# 460 run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20).r(0.85).full		0.7265100716863818	0.000
# 461 run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20).r(0.3).full		0.7264903603916443	0.001
# 462 run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20).r(0.5).full		0.7262456969656598	0.000
# 463 run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20).r(0.4).full		0.7261796505215294	0.000
# 464 run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20).r(0.3).summary		0.7261292117348594	0.003
# 465 run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20).r(0.6).full		0.7256266567822572	0.000
# 466 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40).r(0.2).full		0.7255741156607886	0.002
# 467 run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20).r(1).summary		0.7254847990338965	0.000
# 468 run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20).r(0.3).full		0.7253616812405123	0.001
# 469 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40).r(0.4).summary		0.7253594026629349	0.001
# 470 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0.5).summary		0.7252339448434395	0.001
# 471 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20).r(0.4).summary		0.7252038931245501	0.002
# 472 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20).r(0.8).summary		0.7251109036135536	0.001
# 473 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20).r(1).summary		0.7250817119525154	0.002
# 474 run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20).r(1).full		0.7244073163727021	0.000
# 475 run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20).r(0.8).full		0.7242250861692313	0.000
# 476 run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20).r(0.5).summary		0.7238776696421971	0.000
# 477 run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20).r(0.95).full		0.7236053664260147	0.000
# 478 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0.4).summary		0.7235515625796689	0.001
# 479 run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20).r(0.15).full		0.7234817234314115	0.002
# 480 run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20).r(0.85).full		0.7231839196470312	0.000
# 481 run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20).r(0.3).full		0.7230684077908722	0.000
# 482 run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20).r(0.3).full		0.7230379975130924	0.000
# 483 run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20).r(0.7).full		0.722266153298128	0.000
# 484 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(1).summary		0.7221981249865574	0.000
# 485 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20).r(1).summary		0.7219438970988773	0.000
# 486 run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20).r(0.3).summary		0.721899378419623	0.003
# 487 run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20).r(0.9).full		0.7218306655659062	0.000
# 488 run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20).r(0.3).summary		0.721765023640748	0.002
# 489 run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20).r(0.2).full		0.7214649654668199	0.000
# 490 run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20).r(0.9).full		0.7214488726090043	0.000
# 491 run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20).r(0.3).full		0.7213192729391301	0.001
# 492 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20).r(0.85).summary		0.721282984591704	0.000
# 493 run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20).r(0.7).summary		0.7212571436864512	0.000
# 494 run.Doc2Vec(dm-c,d300,n20,w5,mc5,s1e-05,t8,ep20).r(0.4).full		0.7209245627314641	0.000
# 495 run.Doc2Vec(dm-c,d50,n20,w2,mc5,s1e-05,t4,ep20).r(0.3).summary		0.7209189133216767	0.003
# 496 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40).r(0.7).summary		0.7209117987855124	0.000
# 497 run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20).r(0.3).full		0.7209101293787605	0.000
# 498 run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20).r(0.95).full		0.7208841652839857	0.000
# 499 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0.6).summary		0.7207945689587544	0.000
# 500 run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20).r(0.5).full		0.7207743314643711	0.000
# 501 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40).r(0.2).summary		0.7206779288066134	0.001
# 502 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20).r(0.9).summary		0.7205630562546214	0.000
# 503 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0.85).summary		0.7204909691492261	0.000
# 504 run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20).r(0.6).full		0.7203487990755476	0.000
# 505 run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20).r(1).full		0.72034866796969	0.000
# 506 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0.6).summary		0.7203082547674301	0.000
# 507 run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20).r(0.3).full		0.7201680348849128	0.000
# 508 run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20).r(0.5).summary		0.720135033518614	0.000
# 509 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20).r(0.2).full		0.7200593790487804	0.000
# 510 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0.8).summary		0.7198925979043813	0.000
# 511 run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20).r(0.3).full		0.7198882946786396	0.000
# 512 run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20).r(0.6).summary		0.7197646004578723	0.000
# 513 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0.5).summary		0.7196705959861933	0.000
# 514 run.Doc2Vec(dm-c,d300,n20,w5,mc5,s1e-05,t8,ep20).r(0.3).full		0.7196581225526147	0.000
# 515 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40).r(0.8).summary		0.7195211386879935	0.000
# 516 run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20).r(0.8).summary		0.7194213345230873	0.000
# 517 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40).r(0.15).full		0.7193773549774757	0.001
# 518 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20).r(0.15).full		0.719141731280378	0.002
# 519 run.Doc2Vec(dm-c,d100,n20,w4,mc5,s1e-05,t4,ep20).r(0.6).summary		0.7191261963873147	0.002
# 520 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20).r(0.95).summary		0.7190670795759538	0.000
# 521 run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20).r(0.4).full		0.7190612663841052	0.000
# 522 run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20).r(0.8).full		0.7190506689869165	0.000
# 523 run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20).r(0.5).full		0.7189882936285336	0.000
# 524 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40).r(0.85).summary		0.718795634110182	0.000
# 525 run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20).r(1).full		0.7186365043330448	0.000
# 526 run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20).r(0.6).summary		0.7184336398785872	0.000
# 527 run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20).r(0.5).full		0.7183969688331889	0.000
# 528 run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20).r(0.6).full		0.718375046616089	0.000
# 529 run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20).r(0.95).full		0.7183603401997612	0.000
# 530 run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20).r(0.2).full		0.7183502609680091	0.000
# 531 run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20).r(0.3).full		0.7182908530016335	0.000
# 532 run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20).r(0.3).full		0.7180723342629575	0.000
# 533 run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20).r(0.6).full		0.7179315077496659	0.000
# 534 run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20).r(1).full		0.717764284681038	0.000
# 535 run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20).r(0.9).full		0.7176397840254644	0.000
# 536 run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20).r(0.3).full		0.7176245904570663	0.001
# 537 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0.9).summary		0.7173496387559221	0.000
# 538 run.Doc2Vec(dm-c,d100,n10,w4,mc5,s1e-05,t4,ep20).r(0.3).full		0.7173307201867232	0.000
# 539 run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20).r(0.4).summary		0.7171653819250068	0.000
# 540 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0.3).summary		0.7170769544663103	0.001
# 541 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0.4).summary		0.7170177027892335	0.001
# 542 run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20).r(0.85).full		0.7169607305332788	0.000
# 543 run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20).r(0.4).summary		0.7169544718428964	0.001
# 544 run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20).r(0.95).summary		0.7168989896863458	0.000
# 545 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40).r(0.3).summary		0.7168168088858489	0.001
# 546 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20).r(0.2).full		0.7168023677870986	0.001
# 547 run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20).r(0.85).summary		0.7167955462762842	0.000
# 548 run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20).r(0.9).summary		0.7167026203902748	0.000
# 549 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0.95).summary		0.7165613146496699	0.000
# 550 run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20).r(0.6).full		0.7165432924460503	0.000
# 551 run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20).r(0.2).full		0.716457547988874	0.001
# 552 run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20).r(0.5).full		0.7160861543702043	0.000
# 553 run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20).r(0.7).full		0.7160494209636212	0.000
# 554 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0.7).summary		0.7160483509578579	0.000
# 555 run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20).r(0.2).full		0.7159476726366503	0.000
# 556 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40).r(0.4).summary		0.7156831142834459	0.001
# 557 run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20).r(0.95).full		0.7156194553635739	0.000
# 558 run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20).r(0.4).summary		0.7155665643234984	0.000
# 559 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40).r(0.95).summary		0.7154295442108154	0.000
# 560 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40).r(0.15).full		0.715378813899978	0.001
# 561 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20).r(0.5).summary		0.715347596468485	0.000
# 562 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0.4).summary		0.7149908518229768	0.001
# 563 run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20).r(1).summary		0.7149560882210877	0.000
# 564 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40).r(0.15).full		0.7147921005004653	0.002
# 565 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40).r(0.15).full		0.7146298325406217	0.001
# 566 run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20).r(0.6).summary		0.7144928106601631	0.000
# 567 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0.3).summary		0.7143955305377022	0.001
# 568 run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20).r(0.2).full		0.7141941263867086	0.000
# 569 run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20).r(0.2).full		0.713989229616873	0.001
# 570 run.Doc2Vec(dm-c,d300,n20,w2,mc5,s1e-05,t8,ep20).r(0.7).summary		0.7139764168909726	0.000
# 571 run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20).r(0.6).summary		0.7139550841140695	0.000
# 572 run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20).r(0.2).full		0.713946061312708	0.000
# 573 run.Doc2Vec(dm-c,d300,n20,w5,mc5,s1e-05,t8,ep20).r(0.5).full		0.7138592861866531	0.000
# 574 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(1).summary		0.713828074753795	0.000
# 575 run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20).r(0.2).full		0.7137713071396531	0.001
# 576 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40).r(0.9).summary		0.713573394038346	0.000
# 577 run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20).r(0.7).summary		0.7135457678928547	0.000
# 578 run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20).r(0.2).full		0.7134821772227995	0.000
# 579 run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20).r(0.9).full		0.7133960054187765	0.000
# 580 run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20).r(0.4).summary		0.7133523578495136	0.001
# 581 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40).r(0.5).summary		0.7133487046945665	0.000
# 582 run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20).r(1).full		0.7133136259752791	0.000
# 583 run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20).r(0.4).summary		0.712973763263349	0.000
# 584 run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20).r(0.7).full		0.7128584838460148	0.000
# 585 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20).r(0.2).summary		0.7127302335897239	0.002
# 586 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40).r(0.3).summary		0.7126869405622315	0.000
# 587 run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20).r(0.4).full		0.7126138788335517	0.000
# 588 run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20).r(0.6).summary		0.7126024625685106	0.000
# 589 run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20).r(0.4).full		0.712209383681015	0.000
# 590 run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20).r(0.4).summary		0.7117518212098142	0.001
# 591 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20).r(0.3).summary		0.7116629355352859	0.001
# 592 run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20).r(0.9).summary		0.7116372149521688	0.000
# 593 run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20).r(0.5).summary		0.711509627587973	0.001
# 594 run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20).r(0.15).full		0.7114999718438587	0.001
# 595 run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20).r(0.5).summary		0.7114670013260184	0.000
# 596 run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20).r(0.8).summary		0.7113609484824555	0.000
# 597 run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20).r(0.95).summary		0.711230156849827	0.000
# 598 run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20).r(0.5).summary		0.7110767588202614	0.000
# 599 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20).r(0.95).summary		0.7110365129643808	0.000
# 600 run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20).r(0.85).summary		0.710806938927174	0.000
# 601 run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20).r(0.2).full		0.7106018386586469	0.001
# ...
# 1268 run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20).r(0.05).summary		0.6543009996535033	0.000
# 1269 run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20).r(0).full		0.6541496193964154	0.000
# 1270 run.Doc2Vec(dm-c,d200,n20,w3,mc5,s1e-05,t8,ep20).r(0).summary		0.6541496193964154	0.000
# 1271 run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20).r(0.8).summary		0.6537925532126501	0.000
# 1272 run.Doc2Vec(dm-c,d300,n20,w5,mc5,s1e-05,t8,ep20).r(0).summary		0.6537369857551608	0.000
# 1273 run.Doc2Vec(dm-c,d300,n20,w5,mc5,s1e-05,t8,ep20).r(0).full		0.6537369857551608	0.000
# 1274 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0.05).full		0.6536562200945094	0.000
# 1275 run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20).r(0.05).full		0.6534363362316775	0.000
# 1276 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20).r(0).summary		0.6533660480426706	0.000
# 1277 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep20).r(0).full		0.6533660480426706	0.000
# 1278 run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20).r(0.85).summary		0.6532406884528345	0.000
# 1279 run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20).r(0.05).summary		0.6532396501178748	0.000
# 1280 run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20).r(0.9).summary		0.6529723891952861	0.000
# 1281 run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20).r(0.05).summary		0.6529468288099607	0.000
# 1282 run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20).r(0.05).full		0.652592354483655	0.000
# 1283 run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20).r(0.9).summary		0.6525842895316926	0.000
# 1284 run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20).r(0.85).summary		0.6525665013930831	0.000
# 1285 run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20).r(0.1).summary		0.6525113627039582	0.000
# 1286 run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20).r(0.05).full		0.6523328481894579	0.000
# 1287 run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20).r(0.05).full		0.6520943456765109	0.000
# 1288 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0.05).summary		0.6520827101951725	0.000
# 1289 run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20).r(0.1).summary		0.652009086655428	0.000
# 1290 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20).r(0.05).summary		0.6518811958044802	0.000
# 1291 run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20).r(0).summary		0.6517445389228703	0.000
# 1292 run.Doc2Vec(dm-c,d200,n20,w4,mc5,s1e-05,t8,ep20).r(0).full		0.6517445389228703	0.000
# 1293 run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20).r(0.95).summary		0.6516880917215764	0.000
# 1294 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40).r(0).summary		0.6514632840889768	0.000
# 1295 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep40).r(0).full		0.6514632840889768	0.000
# 1296 run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20).r(0.05).full		0.6514539875678224	0.000
# 1297 run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20).r(1).summary		0.6514282609141576	0.000
# 1298 run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20).r(1).summary		0.6512406514866981	0.000
# 1299 run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20).r(0).full		0.6511146119751138	0.000
# 1300 run.Doc2Vec(dm-c,d75,n20,w2,mc5,s1e-05,t4,ep20).r(0).summary		0.6511146119751138	0.000
# 1301 run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20).r(0.05).full		0.6507739363230335	0.000
# 1302 run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20).r(0.7).summary		0.6505909501663396	0.000
# 1303 run.Doc2Vec(dm-c,d300,n20,w5,mc5,s1e-05,t8,ep20).r(0.95).summary		0.6505851512513922	0.000
# 1304 run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20).r(0.8).summary		0.6502922886197026	0.000
# 1305 run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20).r(0.05).full		0.6502918011764419	0.000
# 1306 run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20).r(0.95).summary		0.6502817775581831	0.000
# 1307 run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20).r(0).full		0.6494539337665733	0.000
# 1308 run.Doc2Vec(dm-c,d300,n20,w3,mc5,s1e-05,t8,ep20).r(0).summary		0.6494539337665733	0.000
# 1309 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40).r(0).summary		0.6490723748047317	0.000
# 1310 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep40).r(0).full		0.6490723748047317	0.000
# 1311 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40).r(0).full		0.6488078372437562	0.000
# 1312 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep40).r(0).summary		0.6488078372437562	0.000
# 1313 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20).r(0).summary		0.648616210980551	0.000
# 1314 run.Doc2Vec(dm-c,d100,n20,w3,mc5,s1e-05,t4,ep20).r(0).full		0.648616210980551	0.000
# 1315 run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20).r(0.1).summary		0.6485432024472075	0.000
# 1316 run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20).r(0.1).summary		0.6483306006948103	0.000
# 1317 run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20).r(0.05).summary		0.6482207537834337	0.000
# 1318 run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20).r(0.85).summary		0.6481919253528191	0.000
# 1319 run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20).r(0).summary		0.6480861703450352	0.000
# 1320 run.Doc2Vec(dm-c,d150,n20,w2,mc5,s1e-05,t4,ep20).r(0).full		0.6480861703450352	0.000
# 1321 run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20).r(1).summary		0.6480373710827629	0.000
# 1322 run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20).r(0.05).summary		0.6474704283695042	0.000
# 1323 run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20).r(0.85).summary		0.6474402567922742	0.000
# 1324 run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20).r(0).summary		0.6473633851501999	0.000
# 1325 run.Doc2Vec(dm-c,d200,n20,w5,mc5,s1e-05,t8,ep20).r(0).full		0.6473633851501999	0.000
# 1326 run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20).r(0.05).summary		0.6473044356062171	0.000
# 1327 run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20).r(0.1).full		0.6472894431109195	0.000
# 1328 run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20).r(0.05).full		0.6471862741819975	0.000
# 1329 run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20).r(0.05).summary		0.6470833275261596	0.000
# 1330 run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20).r(0.9).summary		0.6467559575570913	0.000
# 1331 run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20).r(0).full		0.6467051477096534	0.000
# 1332 run.Doc2Vec(dm-c,d100,n20,w5,mc5,s1e-05,t4,ep20).r(0).summary		0.6467051477096534	0.000
# 1333 run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20).r(0).full		0.6466057550801244	0.000
# 1334 run.Doc2Vec(dm-c,d50,n20,w1,mc5,s1e-05,t4,ep20).r(0).summary		0.6466057550801244	0.000
# 1335 run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20).r(0.05).full		0.6458677738554806	0.000
# 1336 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0).summary		0.6457965949835294	0.000
# 1337 run.Doc2Vec(dm-c,d300,n20,w1,mc5,s1e-05,t8,ep20).r(0).full		0.6457965949835294	0.000
# 1338 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40).r(0).summary		0.6456242850678666	0.000
# 1339 run.Doc2Vec(dm-c,d100,n20,w2,mc5,s1e-05,t4,ep40).r(0).full		0.6456242850678666	0.000
# 1340 run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20).r(0.05).summary		0.6452807863086064	0.000
# 1341 run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20).r(0.95).summary		0.6451057083213704	0.000
# 1342 run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20).r(0.9).summary		0.6447368874441565	0.000
# 1343 run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20).r(1).summary		0.6443019007313365	0.000
# 1344 run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20).r(0.05).summary		0.6442482637345522	0.000
# 1345 run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20).r(0.05).summary		0.6439356776939559	0.000
# 1346 run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20).r(0.05).summary		0.6438891262228678	0.000
# 1347 run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20).r(0.05).summary		0.6438593433843286	0.000
# 1348 run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20).r(0.9).summary		0.6437313929240239	0.000
# 1349 run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20).r(0.95).summary		0.6436813114221903	0.000
# 1350 run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20).r(0.7).summary		0.6436566331418352	0.000
# 1351 run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20).r(0.8).summary		0.6435201973244763	0.000
# 1352 run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20).r(0.1).summary		0.6432116947509573	0.000
# 1353 run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20).r(0).full		0.642927133810794	0.000
# 1354 run.Doc2Vec(dm-c,d300,n10,w3,mc5,s1e-05,t4,ep20).r(0).summary		0.642927133810794	0.000
# 1355 run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20).r(0.05).full		0.6429085735760475	0.000
# 1356 run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20).r(0.05).summary		0.6427851487283662	0.000
# 1357 run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20).r(0).full		0.6427526016905887	0.000
# 1358 run.Doc2Vec(dm-c,d100,n10,w2,mc5,s1e-05,t4,ep20).r(0).summary		0.6427526016905887	0.000
# 1359 run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20).r(0.95).summary		0.6425983780799113	0.000
# 1360 run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20).r(0).full		0.6425663360038322	0.000
# 1361 run.Doc2Vec(dm-c,d150,n20,w4,mc5,s1e-05,t4,ep20).r(0).summary		0.6425663360038322	0.000
# 1362 run.Doc2Vec(dm-c,d300,n20,w5,mc5,s1e-05,t8,ep20).r(1).summary		0.6425185525723452	0.000
# 1363 run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20).r(0.05).full		0.6421481629952044	0.000
# 1364 run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20).r(0.95).summary		0.6418751660728479	0.000
# 1365 run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20).r(0).summary		0.6416920743324257	0.000
# 1366 run.Doc2Vec(dm-c,d300,n10,w1,mc5,s1e-05,t8,ep20).r(0).full		0.6416920743324257	0.000
# 1367 run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20).r(0).summary		0.6415821525791092	0.000
# 1368 run.Doc2Vec(dm-c,d300,n10,w2,mc5,s1e-05,t4,ep20).r(0).full		0.6415821525791092	0.000
# 1369 run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20).r(0.05).full		0.6413977141981324	0.000
# 1370 run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20).r(0).full		0.6405517687507509	0.000
# 1371 run.Doc2Vec(dm-c,d100,n10,w3,mc5,s1e-05,t4,ep20).r(0).summary		0.6405517687507509	0.000
# 1372 run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20).r(0).full		0.6400487292470562	0.000
# 1373 run.Doc2Vec(dm-c,d200,n10,w2,mc5,s1e-05,t4,ep20).r(0).summary		0.6400487292470562	0.000
# 1374 run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20).r(0.05).summary		0.6400224330032651	0.000
# 1375 run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20).r(1).summary		0.63964610026499	0.000
# 1376 run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20).r(0.05).summary		0.6395643215818735	0.000
# 1377 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20).r(0).summary		0.6387336228250257	0.000
# 1378 run.Doc2Vec(dm-c,d100,n20,w1,mc5,s1e-05,t4,ep20).r(0).full		0.6387336228250257	0.000
# 1379 run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20).r(0).summary		0.6387213096835557	0.000
# 1380 run.Doc2Vec(dm-c,d200,n20,w2,mc5,s1e-05,t8,ep20).r(0).full		0.6387213096835557	0.000
# 1381 run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20).r(1).summary		0.6382705641353501	0.000
# 1382 run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20).r(0.05).summary		0.6380134429082195	0.000
# 1383 run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20).r(0).full		0.637951095515617	0.000
# 1384 run.Doc2Vec(dm-c,d150,n20,w5,mc5,s1e-05,t4,ep20).r(0).summary		0.637951095515617	0.000
# 1385 run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20).r(0.85).summary		0.6378060959141998	0.000
# 1386 run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20).r(0.05).summary		0.637348710528181	0.000
# 1387 run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20).r(0).summary		0.6371697557147764	0.000
# 1388 run.Doc2Vec(dm-c,d200,n10,w4,mc5,s1e-05,t4,ep20).r(0).full		0.6371697557147764	0.000
# 1389 run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20).r(0.8).summary		0.636771431401256	0.000
# 1390 run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20).r(0).full		0.6363251472007254	0.000
# 1391 run.Doc2Vec(dm-c,d150,n10,w1,mc5,s1e-05,t4,ep20).r(0).summary		0.6363251472007254	0.000
# 1392 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0).summary		0.6361372986477737	0.000
# 1393 run.Doc2Vec(dm-c,d200,n20,w1,mc5,s1e-05,t8,ep20).r(0).full		0.6361372986477737	0.000
# 1394 run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20).r(0).full		0.6359618244589658	0.000
# 1395 run.Doc2Vec(dm-c,d200,n10,w3,mc5,s1e-05,t4,ep20).r(0).summary		0.6359618244589658	0.000
# 1396 run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20).r(1).summary		0.6356655703440188	0.000
# 1397 run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20).r(0).summary		0.6352808906374094	0.000
# 1398 run.Doc2Vec(dm-c,d300,n20,w4,mc5,s1e-05,t8,ep20).r(0).full		0.6352808906374094	0.000
# 1399 run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20).r(0).summary		0.635250713287238	0.000
# 1400 run.Doc2Vec(dm-c,d150,n20,w1,mc5,s1e-05,t4,ep20).r(0).full		0.635250713287238	0.000
# 1401 run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20).r(0.05).summary		0.6351266466359488	0.000
# 1402 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20).r(0).full		0.6349870551108941	0.000
# 1403 run.Doc2Vec(dm-c,d150,n20,w3,mc5,s1e-05,t4,ep20).r(0).summary		0.6349870551108941	0.000
# 1404 run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20).r(0.05).full		0.6347367745181814	0.000
# 1405 run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20).r(0.85).summary		0.6346129512111658	0.000
# 1406 run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20).r(0).full		0.6323438695612081	0.000
# 1407 run.Doc2Vec(dm-c,d150,n10,w2,mc5,s1e-05,t4,ep20).r(0).summary		0.6323438695612081	0.000
# 1408 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0).full		0.6321333152920674	0.000
# 1409 run.Doc2Vec(dm-c,d200,n10,w1,mc5,s1e-05,t8,ep20).r(0).summary		0.6321333152920674	0.000
# 1410 run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20).r(0.7).summary		0.6318062525960058	0.000
# 1411 run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20).r(0.9).summary		0.6317708794262438	0.000
# 1412 run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20).r(0).summary		0.6312375143776178	0.000
# 1413 run.Doc2Vec(dm-c,d150,n10,w3,mc5,s1e-05,t4,ep20).r(0).full		0.6312375143776178	0.000
# 1414 run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20).r(0).full		0.6299297046978196	0.000
# 1415 run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20).r(0).summary		0.6299297046978196	0.000
# 1416 run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20).r(0).full		0.6295598554746245	0.000
# 1417 run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20).r(0).summary		0.6295598554746245	0.000
# 1418 run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20).r(0).summary		0.6293429195021425	0.000
# 1419 run.Doc2Vec(dm-c,d150,n10,w5,mc5,s1e-05,t4,ep20).r(0).full		0.6293429195021425	0.000
# 1420 run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20).r(0).full		0.6293387083817479	0.000
# 1421 run.Doc2Vec(dm-c,d75,n20,w1,mc5,s1e-05,t4,ep20).r(0).summary		0.6293387083817479	0.000
# 1422 run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20).r(0.95).summary		0.6285938355577764	0.000
# 1423 run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20).r(0).full		0.6275741448728933	0.000
# 1424 run.Doc2Vec(dm-c,d100,n10,w1,mc5,s1e-05,t4,ep20).r(0).summary		0.6275741448728933	0.000
# 1425 run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20).r(0.9).summary		0.6267732533355509	0.000
# 1426 run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20).r(1).summary		0.6261994835670995	0.000
# 1427 run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20).r(0.8).summary		0.6240420236242306	0.000
# 1428 run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20).r(0.95).summary		0.6239972784534611	0.000
# 1429 run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20).r(0).full		0.6234621495801134	0.000
# 1430 run.Doc2Vec(dm-c,d100,n10,w5,mc5,s1e-05,t4,ep20).r(0).summary		0.6234621495801134	0.000
# 1431 run.Doc2Vec(dm-c,d300,n10,w4,mc5,s1e-05,t8,ep20).r(1).summary		0.6232081030361023	0.000
# 1432 run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20).r(0).summary		0.6198351868161384	0.000
# 1433 run.Doc2Vec(dm-c,d300,n10,w5,mc5,s1e-05,t8,ep20).r(0).full		0.6198351868161384	0.000
# 1434 run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20).r(0).summary		0.6191633771591685	0.000
# 1435 run.Doc2Vec(dm-c,d150,n10,w4,mc5,s1e-05,t4,ep20).r(0).full		0.6191633771591685	0.000
# 1436 run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20).r(0.85).summary		0.6159929578632043	0.000
# 1437 run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20).r(0.9).summary		0.6134980193052173	0.000
# 1438 run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20).r(0.95).summary		0.6109916920909951	0.000
# 1439 run.Doc2Vec(dm-c,d200,n10,w5,mc5,s1e-05,t4,ep20).r(1).summary		0.6067892502618344	0.000

# %%
results_df.loc[results_df.index[i], "ndcg"]

# %%
first_run = results_df.index[0]
second_run = results_df.index[11]

print(results_df.loc[first_run], "\n")
print(results_df.loc[second_run])
